# %% [markdown]
# <a href="https://colab.research.google.com/github/SRAVANIDHARA/Pointnet/blob/master/Pointnet_Training_and_Evaluate_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Setup HyperOpt

# %%
# !pip install hyperopt
# Out:
# Requirement already satisfied: hyperopt in /usr/local/lib/python3.6/dist-packages (0.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from hyperopt) (4.28.1)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.6/dist-packages (from hyperopt) (3.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.17.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.12.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.4.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.6/dist-packages (from hyperopt) (2.4)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from hyperopt) (0.16.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx->hyperopt) (4.4.1)

# %% [markdown]
# ## Running pointnet
#
# Mount the google drive and point to the folder containing the train.py and run the code from there with a slight modification.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os

os.chdir('/content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet')

# %%
#!ls
# !python train.py --max_epoch=4 --run_mode='hyperopt' --log_dir="log/hyperopt" --max_evals=2 --max_trials=2
# Out:
# Log dir:log/hyperopt already exists! creating a new one.
# New log dir:log/hyperopt/7
# 1:Starting the run with the mode:hyperopt
# Namespace(batch_size=32, decay_rate=0.7, decay_step=200000, gpu=0, learning_rate=0.001, log_dir='log/hyperopt', max_epoch=4, max_evals=2, max_trials=2, model='pointnet_cls', model_path='', momentum=0.9, mongo_mode=0, num_point=1024, optimizer='adam', run_mode='hyperopt', trials_path='')
#
# Starting hyperopt
# HyperOpt batch size selected:32
#   0% 0/2 [00:00<?, ?it/s, best loss: ?]WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/models/pointnet_cls.py:13: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#   0% 0/2 [00:01<?, ?it/s, best loss: ?]WARNING:tensorflow:From train.py:133: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From train.py:160: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/models/pointnet_cls.py:24: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:21: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:48: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:368: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:Variable += will be deprecated. Use variable.assign_add if you want assignment to the variable value or 'x = x + y' if you want a new python Tensor object.
# WARNING:tensorflow:Variable += will be deprecated. Use variable.assign_add if you want assignment to the variable value or 'x = x + y' if you want a new python Tensor object.
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:573: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From train.py:167: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From train.py:177: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From train.py:181: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From train.py:184: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From train.py:188: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-03-16 11:14:09.211294: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-03-16 11:14:09.213942: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1e33100 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-03-16 11:14:09.213977: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-03-16 11:14:09.221483: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-03-16 11:14:09.396560: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:14:09.397593: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1e332c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-03-16 11:14:09.397624: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-03-16 11:14:09.398938: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:14:09.399823: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-03-16 11:14:09.416318: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-16 11:14:09.672959: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-16 11:14:09.803396: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-16 11:14:09.825707: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-16 11:14:10.104075: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-16 11:14:10.127892: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-16 11:14:10.642530: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-16 11:14:10.642765: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:14:10.643792: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:14:10.644582: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-16 11:14:10.648805: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-16 11:14:10.650471: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-16 11:14:10.650510: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-16 11:14:10.650524: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-16 11:14:10.651844: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:14:10.652743: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:14:10.653599: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# WARNING:tensorflow:From train.py:201: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From train.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From train.py:210: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# 2020-03-16 11:14:11.249785: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
#   0% 0/2 [00:15<?, ?it/s, best loss: ?]2020-03-16 11:14:21.729413: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-16 11:14:23.179783: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# mean loss: 3.698796
# accuracy: 0.223633
# ----1-----
# mean loss: 2.708016
# accuracy: 0.331543
# ----2-----
# mean loss: 2.367219
# accuracy: 0.396484
# ----3-----
# mean loss: 2.061304
# accuracy: 0.445312
# ----4-----
# mean loss: 1.779174
# accuracy: 0.519608
# ----0-----
# ----1-----
# eval mean loss: 1.685977
# eval accuracy: 0.542208
# eval avg class acc: 0.408944
# --- Total running time for EPOCH 000 : 0:01:08.765423 ---
# Model saved in file: log/hyperopt/7/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 1.797032
# accuracy: 0.497070
# ----1-----
# mean loss: 1.547839
# accuracy: 0.557129
# ----2-----
# mean loss: 1.527715
# accuracy: 0.553922
# ----3-----
# mean loss: 1.416455
# accuracy: 0.605957
# ----4-----
# mean loss: 1.368199
# accuracy: 0.601562
# ----0-----
# ----1-----
# eval mean loss: 1.201921
# eval accuracy: 0.650568
# eval avg class acc: 0.542555
# --- Total running time for EPOCH 001 : 0:00:45.089542 ---
# **** EPOCH 002 ****
# ----0-----
# mean loss: 1.307706
# accuracy: 0.625977
# ----1-----
# mean loss: 1.281220
# accuracy: 0.621094
# ----2-----
# mean loss: 1.220401
# accuracy: 0.644531
# ----3-----
# mean loss: 1.245970
# accuracy: 0.633578
# ----4-----
# mean loss: 1.204678
# accuracy: 0.665527
# ----0-----
# ----1-----
# eval mean loss: 0.979834
# eval accuracy: 0.717938
# eval avg class acc: 0.632610
# --- Total running time for EPOCH 002 : 0:00:45.037888 ---
# **** EPOCH 003 ****
# ----0-----
# mean loss: 1.079353
# accuracy: 0.682129
# ----1-----
# mean loss: 1.141910
# accuracy: 0.666992
# ----2-----
# mean loss: 1.078571
# accuracy: 0.686035
# ----3-----
# mean loss: 1.808236
# accuracy: 0.625488
# ----4-----
# mean loss: 9.922659
# accuracy: 0.216912
# ----0-----
# ----1-----
# eval mean loss: 2.492186
# eval accuracy: 0.280032
# eval avg class acc: 0.199566
# --- Total running time for EPOCH 003 : 0:00:45.190249 ---
# --- Total running time for MAIN : 0:03:39.253288 ---
# HyperOpt batch size selected:2
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#  50% 1/2 [03:40<03:40, 220.62s/it, best loss: 2.492185987435378]2020-03-16 11:17:46.697773: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:17:46.698712: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-03-16 11:17:46.698833: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-16 11:17:46.698881: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-16 11:17:46.699097: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-16 11:17:46.699176: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-16 11:17:46.699265: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-16 11:17:46.699320: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-16 11:17:46.699405: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-16 11:17:46.699615: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:17:46.700544: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:17:46.701342: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-16 11:17:46.701436: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-16 11:17:46.701468: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-16 11:17:46.701495: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-16 11:17:46.701670: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:17:46.702647: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:17:46.703585: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# 2020-03-16 11:17:47.447469: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
# mean loss: 6.843843
# accuracy: 0.068359
# ----1-----
# mean loss: 5.189651
# accuracy: 0.063714
# ----2-----
# mean loss: 4.081912
# accuracy: 0.090332
# ----3-----
# mean loss: 4.044043
# accuracy: 0.110840
# ----4-----
# mean loss: 3.712774
# accuracy: 0.090332
# ----0-----
# ----1-----
# eval mean loss: 100753.704368
# eval accuracy: 0.025122
# eval avg class acc: 0.015500
# --- Total running time for EPOCH 000 : 0:02:59.588825 ---
# Model saved in file: log/hyperopt/7/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 3.631796
# accuracy: 0.103516
# ----1-----
# mean loss: 3.542720
# accuracy: 0.105583
# ----2-----
# mean loss: 3.437191
# accuracy: 0.113281
# ----3-----
# mean loss: 3.689489
# accuracy: 0.098145
# ----4-----
# mean loss: 3.446969
# accuracy: 0.121582
# ----0-----
# ----1-----
# eval mean loss: 5984738.484042
# eval accuracy: 0.047407
# eval avg class acc: 0.029250
# --- Total running time for EPOCH 001 : 0:02:53.896370 ---
# **** EPOCH 002 ****
# ----0-----
# mean loss: 3.411766
# accuracy: 0.126465
# ----1-----
# mean loss: 3.384189
# accuracy: 0.129395
# ----2-----
# mean loss: 3.364060
# accuracy: 0.130461
# ----3-----
# mean loss: 3.373913
# accuracy: 0.108887
# ----4-----
# mean loss: 3.457958
# accuracy: 0.103516
# ----0-----
# ----1-----
# eval mean loss: 275309.133020
# eval accuracy: 0.065235
# eval avg class acc: 0.040250
# --- Total running time for EPOCH 002 : 0:02:53.456734 ---
# **** EPOCH 003 ****
# ----0-----
# mean loss: 3.393454
# accuracy: 0.127930
# ----1-----
# mean loss: 3.384235
# accuracy: 0.124023
# ----2-----
# mean loss: 3.352153
# accuracy: 0.132812
# ----3-----
# mean loss: 3.368116
# accuracy: 0.116211
# ----4-----
# mean loss: 3.337682
# accuracy: 0.115291
# ----0-----
# ----1-----
# eval mean loss: 2427.736005
# eval accuracy: 0.010130
# eval avg class acc: 0.006250
# --- Total running time for EPOCH 003 : 0:02:52.478303 ---
# --- Total running time for MAIN : 0:11:45.636149 ---
# 100% 2/2 [15:26<00:00, 366.14s/it, best loss: 2.492185987435378]
# Run 1 - Best param found:{'batch_size': 4}
# {'state': 2, 'tid': 0, 'spec': None, 'result': {'loss': 2.492185987435378, 'status': 'ok', 'accuracy': 0.2800324675324675, 'avg_class_accuracy': 0.19956557147171766, 'eval_time': 1584357462.5242972, 'RunParams': {'optimizer': 'adam', 'batch_size': 32, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 4}}, 'misc': {'tid': 0, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [0]}, 'vals': {'batch_size': [4]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 11, 14, 1, 959000), 'refresh_time': datetime.datetime(2020, 3, 16, 11, 17, 42, 577000)}
# {'state': 2, 'tid': 1, 'spec': None, 'result': {'loss': 2427.736005287889, 'status': 'ok', 'accuracy': 0.01012965964343598, 'avg_class_accuracy': 0.00625, 'eval_time': 1584358168.1856441, 'RunParams': {'optimizer': 'adam', 'batch_size': 2, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 4}}, 'misc': {'tid': 1, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [1]}, 'vals': {'batch_size': [0]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 11, 17, 42, 581000), 'refresh_time': datetime.datetime(2020, 3, 16, 11, 29, 28, 237000)}
# Written trials on run 1.
# HyperOpt batch size selected:8
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#   0% 0/2 [00:00<?, ?it/s, best loss: ?]2020-03-16 11:29:32.214133: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:29:32.214922: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-03-16 11:29:32.215024: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-16 11:29:32.215058: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-16 11:29:32.215083: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-16 11:29:32.215107: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-16 11:29:32.215131: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-16 11:29:32.215154: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-16 11:29:32.215178: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-16 11:29:32.215265: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:29:32.216092: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:29:32.216792: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-16 11:29:32.216837: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-16 11:29:32.216851: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-16 11:29:32.216861: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-16 11:29:32.216966: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:29:32.217719: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:29:32.218478: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# 2020-03-16 11:29:32.838672: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
# mean loss: 3.863926
# accuracy: 0.131836
# ----1-----
# mean loss: 3.216828
# accuracy: 0.183859
# ----2-----
# mean loss: 3.032486
# accuracy: 0.202637
# ----3-----
# mean loss: 2.900973
# accuracy: 0.236816
# ----4-----
# mean loss: 2.657122
# accuracy: 0.270020
# ----0-----
# ----1-----
# eval mean loss: 2.718112
# eval accuracy: 0.250406
# eval avg class acc: 0.175890
# --- Total running time for EPOCH 000 : 0:01:05.962748 ---
# Model saved in file: log/hyperopt/7/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 2.486986
# accuracy: 0.301758
# ----1-----
# mean loss: 2.669122
# accuracy: 0.273438
# ----2-----
# mean loss: 2.339719
# accuracy: 0.332031
# ----3-----
# mean loss: 2.281235
# accuracy: 0.332031
# ----4-----
# mean loss: 2.026734
# accuracy: 0.404126
# ----0-----
# ----1-----
# eval mean loss: 1.709385
# eval accuracy: 0.477679
# eval avg class acc: 0.395222
# --- Total running time for EPOCH 001 : 0:01:04.477956 ---
# **** EPOCH 002 ****
# ----0-----
# mean loss: 1.988399
# accuracy: 0.410801
# ----1-----
# mean loss: 1.810554
# accuracy: 0.451660
# ----2-----
# mean loss: 1.831988
# accuracy: 0.450195
# ----3-----
# mean loss: 1.779211
# accuracy: 0.484863
# ----4-----
# mean loss: 1.696499
# accuracy: 0.506348
# ----0-----
# ----1-----
# eval mean loss: 1.462472
# eval accuracy: 0.560877
# eval avg class acc: 0.471747
# --- Total running time for EPOCH 002 : 0:01:04.242083 ---
# **** EPOCH 003 ****
# ----0-----
# mean loss: 1.620637
# accuracy: 0.515777
# ----1-----
# mean loss: 1.576870
# accuracy: 0.531738
# ----2-----
# mean loss: 1.532783
# accuracy: 0.548340
# ----3-----
# mean loss: 1.478904
# accuracy: 0.545898
# ----4-----
# mean loss: 1.404420
# accuracy: 0.568848
# ----0-----
# ----1-----
# eval mean loss: 1.206521
# eval accuracy: 0.640422
# eval avg class acc: 0.571359
# --- Total running time for EPOCH 003 : 0:01:04.347455 ---
# --- Total running time for MAIN : 0:04:24.898239 ---
# HyperOpt batch size selected:32
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#  50% 1/2 [04:24<04:24, 264.92s/it, best loss: 1.2065209326902768]2020-03-16 11:33:57.276539: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:33:57.277281: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-03-16 11:33:57.277422: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-16 11:33:57.277483: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-16 11:33:57.277531: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-16 11:33:57.277557: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-16 11:33:57.277606: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-16 11:33:57.277665: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-16 11:33:57.277731: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-16 11:33:57.277845: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:33:57.278588: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:33:57.279223: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-16 11:33:57.279300: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-16 11:33:57.279319: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-16 11:33:57.279330: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-16 11:33:57.279457: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:33:57.280326: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:33:57.281001: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# 2020-03-16 11:33:58.063695: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
# mean loss: 3.836036
# accuracy: 0.198730
# ----1-----
# mean loss: 2.743481
# accuracy: 0.336426
# ----2-----
# mean loss: 2.272240
# accuracy: 0.404297
# ----3-----
# mean loss: 2.013492
# accuracy: 0.449219
# ----4-----
# mean loss: 1.845582
# accuracy: 0.487745
# ----0-----
# ----1-----
# eval mean loss: 1.621047
# eval accuracy: 0.538961
# eval avg class acc: 0.461274
# --- Total running time for EPOCH 000 : 0:00:47.204346 ---
# Model saved in file: log/hyperopt/7/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 1.734863
# accuracy: 0.510417
# ----1-----
# mean loss: 1.672454
# accuracy: 0.541504
# ----2-----
# mean loss: 1.636024
# accuracy: 0.540527
# ----3-----
# mean loss: 1.514459
# accuracy: 0.574707
# ----4-----
# mean loss: 1.338854
# accuracy: 0.628906
# ----0-----
# ----1-----
# eval mean loss: 1.292070
# eval accuracy: 0.626218
# eval avg class acc: 0.562520
# --- Total running time for EPOCH 001 : 0:00:45.331055 ---
# **** EPOCH 002 ****
# ----0-----
# mean loss: 1.350954
# accuracy: 0.619141
# ----1-----
# mean loss: 1.244815
# accuracy: 0.639160
# ----2-----
# mean loss: 1.262757
# accuracy: 0.638672
# ----3-----
# mean loss: 1.222057
# accuracy: 0.658203
# ----4-----
# mean loss: 1.197961
# accuracy: 0.666667
# ----0-----
# ----1-----
# eval mean loss: 1.090269
# eval accuracy: 0.694399
# eval avg class acc: 0.624413
# --- Total running time for EPOCH 002 : 0:00:45.529262 ---
# **** EPOCH 003 ****
# ----0-----
# mean loss: 1.200069
# accuracy: 0.656738
# ----1-----
# mean loss: 1.147150
# accuracy: 0.673828
# ----2-----
# mean loss: 1.154508
# accuracy: 0.671875
# ----3-----
# mean loss: 1.047862
# accuracy: 0.682598
# ----4-----
# mean loss: 1.052716
# accuracy: 0.700195
# ----0-----
# ----1-----
# eval mean loss: 0.948764
# eval accuracy: 0.725244
# eval avg class acc: 0.641470
# --- Total running time for EPOCH 003 : 0:00:45.331908 ---
# --- Total running time for MAIN : 0:03:09.711550 ---
# 100% 2/2 [07:34<00:00, 242.36s/it, best loss: 0.9487635613261879]
# Run 2 - Best param found:{'batch_size': 4}
# {'state': 2, 'tid': 0, 'spec': None, 'result': {'loss': 2.492185987435378, 'status': 'ok', 'accuracy': 0.2800324675324675, 'avg_class_accuracy': 0.19956557147171766, 'eval_time': 1584357462.5242972, 'RunParams': {'optimizer': 'adam', 'batch_size': 32, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 4}}, 'misc': {'tid': 0, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [0]}, 'vals': {'batch_size': [4]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 11, 14, 1, 959000), 'refresh_time': datetime.datetime(2020, 3, 16, 11, 17, 42, 577000)}
# {'state': 2, 'tid': 1, 'spec': None, 'result': {'loss': 2427.736005287889, 'status': 'ok', 'accuracy': 0.01012965964343598, 'avg_class_accuracy': 0.00625, 'eval_time': 1584358168.1856441, 'RunParams': {'optimizer': 'adam', 'batch_size': 2, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 4}}, 'misc': {'tid': 1, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [1]}, 'vals': {'batch_size': [0]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 11, 17, 42, 581000), 'refresh_time': datetime.datetime(2020, 3, 16, 11, 29, 28, 237000)}
# {'state': 2, 'tid': 2, 'spec': None, 'result': {'loss': 1.2065209326902768, 'status': 'ok', 'accuracy': 0.640422077922078, 'avg_class_accuracy': 0.5713593073593073, 'eval_time': 1584358433.1211312, 'RunParams': {'optimizer': 'adam', 'batch_size': 8, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 4}}, 'misc': {'tid': 2, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [2]}, 'vals': {'batch_size': [2]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 11, 29, 28, 256000), 'refresh_time': datetime.datetime(2020, 3, 16, 11, 33, 53, 171000)}
# {'state': 2, 'tid': 3, 'spec': None, 'result': {'loss': 0.9487635613261879, 'status': 'ok', 'accuracy': 0.7252435064935064, 'avg_class_accuracy': 0.6414700313529217, 'eval_time': 1584358622.8488803, 'RunParams': {'optimizer': 'adam', 'batch_size': 32, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 4}}, 'misc': {'tid': 3, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [3]}, 'vals': {'batch_size': [4]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 11, 33, 53, 173000), 'refresh_time': datetime.datetime(2020, 3, 16, 11, 37, 2, 903000)}
# Written trials on run 2.

# %%
import os
os.chdir('/content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet')
#!ls
# !python train.py --max_epoch=2 --run_mode='normal' --log_dir="log/normal32" --batch_size=32
#--max_evals=5  --max_trials=10
# Out:
# Log dir:log/normal32 already exists! creating a new one.
# New log dir:log/normal32/6
# 1:Starting the run with the mode:normal
# Namespace(batch_size=32, decay_rate=0.7, decay_step=200000, gpu=0, learning_rate=0.001, log_dir='log/normal32', max_epoch=2, max_evals=1, max_trials=10, model='pointnet_cls', model_path='', momentum=0.9, mongo_mode=0, num_point=1024, optimizer='adam', run_mode='normal', trials_path='')
#
# Starting normal run
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/models/pointnet_cls.py:13: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
# WARNING:tensorflow:From train.py:133: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From train.py:160: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/models/pointnet_cls.py:24: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:21: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:48: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:368: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:Variable += will be deprecated. Use variable.assign_add if you want assignment to the variable value or 'x = x + y' if you want a new python Tensor object.
# WARNING:tensorflow:Variable += will be deprecated. Use variable.assign_add if you want assignment to the variable value or 'x = x + y' if you want a new python Tensor object.
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:573: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From train.py:167: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From train.py:177: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From train.py:181: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From train.py:184: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From train.py:188: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-03-16 11:37:14.983012: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-03-16 11:37:14.983220: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2a8f100 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-03-16 11:37:14.983254: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-03-16 11:37:14.985216: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-03-16 11:37:15.094148: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:37:15.095176: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2a8f2c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-03-16 11:37:15.095204: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-03-16 11:37:15.095409: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:37:15.096164: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-03-16 11:37:15.096485: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-16 11:37:15.097939: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-16 11:37:15.099549: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-16 11:37:15.099826: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-16 11:37:15.101619: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-16 11:37:15.102312: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-16 11:37:15.105934: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-16 11:37:15.106048: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:37:15.107012: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:37:15.107928: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-16 11:37:15.107983: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-16 11:37:15.109593: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-16 11:37:15.109620: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-16 11:37:15.109632: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-16 11:37:15.109767: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:37:15.110627: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:37:15.111447: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# WARNING:tensorflow:From train.py:201: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From train.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From train.py:210: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# 2020-03-16 11:37:15.741755: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
# 2020-03-16 11:37:18.480158: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-16 11:37:18.773731: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# mean loss: 3.808802
# accuracy: 0.198242
# ----1-----
# mean loss: 2.764284
# accuracy: 0.314453
# ----2-----
# mean loss: 2.427237
# accuracy: 0.383578
# ----3-----
# mean loss: 2.127886
# accuracy: 0.431152
# ----4-----
# mean loss: 1.911916
# accuracy: 0.473633
# ----0-----
# ----1-----
# eval mean loss: 1.620612
# eval accuracy: 0.530844
# eval avg class acc: 0.435155
# --- Total running time for EPOCH 000 : 0:00:48.224936 ---
# Model saved in file: log/normal32/6/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 1.667047
# accuracy: 0.514706
# ----1-----
# mean loss: 1.589594
# accuracy: 0.542969
# ----2-----
# mean loss: 1.574368
# accuracy: 0.553223
# ----3-----
# mean loss: 1.739923
# accuracy: 0.507812
# ----4-----
# mean loss: 1.532007
# accuracy: 0.555176
# ----0-----
# ----1-----
# eval mean loss: 1.346116
# eval accuracy: 0.581981
# eval avg class acc: 0.494986
# --- Total running time for EPOCH 001 : 0:00:45.174828 ---
# --- Total running time for MAIN : 0:01:41.049964 ---

# %%
import os
os.chdir('/content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet')
#!ls
# !python train.py --max_epoch=2 --run_mode='normal' --log_dir="log/normal16" --batch_size=16
#--max_evals=5  --max_trials=10
# Out:
# Log dir:log/normal16 already exists! creating a new one.
# New log dir:log/normal16/4
# 1:Starting the run with the mode:normal
# Namespace(batch_size=16, decay_rate=0.7, decay_step=200000, gpu=0, learning_rate=0.001, log_dir='log/normal16', max_epoch=2, max_evals=1, max_trials=10, model='pointnet_cls', model_path='', momentum=0.9, mongo_mode=0, num_point=1024, optimizer='adam', run_mode='normal', trials_path='')
#
# Starting normal run
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/models/pointnet_cls.py:13: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
# WARNING:tensorflow:From train.py:133: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From train.py:160: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/models/pointnet_cls.py:24: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:21: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:48: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:368: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:Variable += will be deprecated. Use variable.assign_add if you want assignment to the variable value or 'x = x + y' if you want a new python Tensor object.
# WARNING:tensorflow:Variable += will be deprecated. Use variable.assign_add if you want assignment to the variable value or 'x = x + y' if you want a new python Tensor object.
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:573: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From train.py:167: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From train.py:177: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From train.py:181: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From train.py:184: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From train.py:188: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-03-16 11:39:00.999586: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-03-16 11:39:00.999826: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1ba9100 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-03-16 11:39:00.999861: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-03-16 11:39:01.002626: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-03-16 11:39:01.116426: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:39:01.117586: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1ba92c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-03-16 11:39:01.117642: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-03-16 11:39:01.117865: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:39:01.118725: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-03-16 11:39:01.119068: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-16 11:39:01.120683: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-16 11:39:01.122278: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-16 11:39:01.122838: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-16 11:39:01.124491: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-16 11:39:01.125197: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-16 11:39:01.128354: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-16 11:39:01.128529: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:39:01.129574: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:39:01.130660: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-16 11:39:01.130785: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-16 11:39:01.132470: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-16 11:39:01.132500: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-16 11:39:01.132513: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-16 11:39:01.132653: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:39:01.133623: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:39:01.134579: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# WARNING:tensorflow:From train.py:201: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From train.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From train.py:210: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# 2020-03-16 11:39:01.744768: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
# 2020-03-16 11:39:04.416784: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-16 11:39:04.716455: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# mean loss: 3.820527
# accuracy: 0.176578
# ----1-----
# mean loss: 2.889916
# accuracy: 0.257324
# ----2-----
# mean loss: 2.507183
# accuracy: 0.337402
# ----3-----
# mean loss: 2.380965
# accuracy: 0.360352
# ----4-----
# mean loss: 2.047767
# accuracy: 0.422363
# ----0-----
# ----1-----
# eval mean loss: 4.273118
# eval accuracy: 0.413149
# eval avg class acc: 0.330048
# --- Total running time for EPOCH 000 : 0:00:54.544408 ---
# Model saved in file: log/normal16/4/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 1.934328
# accuracy: 0.432646
# ----1-----
# mean loss: 1.822581
# accuracy: 0.471191
# ----2-----
# mean loss: 1.767474
# accuracy: 0.473633
# ----3-----
# mean loss: 1.680174
# accuracy: 0.513184
# ----4-----
# mean loss: 1.599607
# accuracy: 0.529297
# ----0-----
# ----1-----
# eval mean loss: 1.278190
# eval accuracy: 0.623782
# eval avg class acc: 0.529058
# --- Total running time for EPOCH 001 : 0:00:51.233086 ---
# --- Total running time for MAIN : 0:01:53.325698 ---

# %%
import os
#os.chdir('/content/drive/My Drive/KE5208_Sense_Making/Code/pointnet00/')
os.chdir('/content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/')


# !python train.py --max_epoch=2 --run_mode='hyperopt' --log_dir="log/hyperopt88" --max_evals=2  --max_trials=2
# --batch_size=16 #--log_dir="log"
# Out:
# Log dir:log/hyperopt88 already exists! creating a new one.
# New log dir:log/hyperopt88/1
# 1:Starting the run with the mode:hyperopt
# Namespace(batch_size=32, decay_rate=0.7, decay_step=200000, gpu=0, learning_rate=0.001, log_dir='log/hyperopt88', max_epoch=2, max_evals=2, max_trials=2, model='pointnet_cls', model_path='', momentum=0.9, mongo_mode=0, num_point=1024, optimizer='adam', run_mode='hyperopt', trials_path='')
#
# Starting hyperopt
# HyperOpt batch size selected:4
#   0% 0/2 [00:00<?, ?it/s, best loss: ?]WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/models/pointnet_cls.py:13: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#   0% 0/2 [00:00<?, ?it/s, best loss: ?]WARNING:tensorflow:From train.py:133: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From train.py:160: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/models/pointnet_cls.py:24: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:21: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:48: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:368: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:Variable += will be deprecated. Use variable.assign_add if you want assignment to the variable value or 'x = x + y' if you want a new python Tensor object.
# WARNING:tensorflow:Variable += will be deprecated. Use variable.assign_add if you want assignment to the variable value or 'x = x + y' if you want a new python Tensor object.
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:573: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From train.py:167: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From train.py:177: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From train.py:181: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From train.py:184: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From train.py:188: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-03-16 11:41:00.078616: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-03-16 11:41:00.078863: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2719100 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-03-16 11:41:00.078917: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-03-16 11:41:00.082198: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-03-16 11:41:00.193809: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:41:00.194992: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x27192c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-03-16 11:41:00.195050: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-03-16 11:41:00.195326: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:41:00.196255: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-03-16 11:41:00.196764: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-16 11:41:00.198734: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-16 11:41:00.200602: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-16 11:41:00.201148: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-16 11:41:00.203086: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-16 11:41:00.203991: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-16 11:41:00.207764: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-16 11:41:00.207909: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:41:00.208895: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:41:00.209819: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-16 11:41:00.209889: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-16 11:41:00.211573: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-16 11:41:00.211608: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-16 11:41:00.211626: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-16 11:41:00.211780: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:41:00.212718: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:41:00.213596: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# WARNING:tensorflow:From train.py:201: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From train.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From train.py:210: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# 2020-03-16 11:41:00.784666: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
#   0% 0/2 [00:06<?, ?it/s, best loss: ?]2020-03-16 11:41:03.438007: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-16 11:41:03.737086: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# mean loss: 4.256939
# accuracy: 0.092233
# ----1-----
# mean loss: 3.511559
# accuracy: 0.117188
# ----2-----
# mean loss: 3.415780
# accuracy: 0.132324
# ----3-----
# mean loss: 3.385632
# accuracy: 0.130859
# ----4-----
# mean loss: 3.209973
# accuracy: 0.155762
# ----0-----
# ----1-----
# eval mean loss: 3.664662
# eval accuracy: 0.153566
# eval avg class acc: 0.094750
# --- Total running time for EPOCH 000 : 0:01:40.100940 ---
# Model saved in file: log/hyperopt88/1/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 3.125042
# accuracy: 0.157160
# ----1-----
# mean loss: 3.005398
# accuracy: 0.181641
# ----2-----
# mean loss: 2.969587
# accuracy: 0.190430
# ----3-----
# mean loss: 2.885270
# accuracy: 0.215820
# ----4-----
# mean loss: 2.855829
# accuracy: 0.210938
# ----0-----
# ----1-----
# eval mean loss: 5.246095
# eval accuracy: 0.262966
# eval avg class acc: 0.164430
# --- Total running time for EPOCH 001 : 0:01:37.149114 ---
# --- Total running time for MAIN : 0:03:24.777412 ---
# HyperOpt batch size selected:16
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#  50% 1/2 [03:24<03:24, 204.80s/it, best loss: 5.246095087868275]2020-03-16 11:44:23.856677: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:44:23.857616: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-03-16 11:44:23.857704: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-16 11:44:23.857736: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-16 11:44:23.857762: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-16 11:44:23.857786: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-16 11:44:23.857810: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-16 11:44:23.857850: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-16 11:44:23.857875: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-16 11:44:23.857964: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:44:23.858751: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:44:23.859462: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-16 11:44:23.859539: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-16 11:44:23.859557: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-16 11:44:23.859567: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-16 11:44:23.859696: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:44:23.860833: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:44:23.861782: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# 2020-03-16 11:44:24.498478: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
# mean loss: 4.002627
# accuracy: 0.149272
# ----1-----
# mean loss: 3.109801
# accuracy: 0.244629
# ----2-----
# mean loss: 2.643023
# accuracy: 0.313477
# ----3-----
# mean loss: 2.523347
# accuracy: 0.312988
# ----4-----
# mean loss: 2.271386
# accuracy: 0.378418
# ----0-----
# ----1-----
# eval mean loss: 1.976032
# eval accuracy: 0.433036
# eval avg class acc: 0.326219
# --- Total running time for EPOCH 000 : 0:00:53.820225 ---
# Model saved in file: log/hyperopt88/1/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 2.032663
# accuracy: 0.403809
# ----1-----
# mean loss: 1.895987
# accuracy: 0.441406
# ----2-----
# mean loss: 1.771387
# accuracy: 0.483398
# ----3-----
# mean loss: 1.656574
# accuracy: 0.512743
# ----4-----
# mean loss: 1.578858
# accuracy: 0.533691
# ----0-----
# ----1-----
# eval mean loss: 1.282311
# eval accuracy: 0.611201
# eval avg class acc: 0.515767
# --- Total running time for EPOCH 001 : 0:00:52.255355 ---
# --- Total running time for MAIN : 0:01:52.088619 ---
# 100% 2/2 [05:16<00:00, 176.99s/it, best loss: 1.2823111887102003]
# Run 1 - Best param found:{'batch_size': 3}
# {'state': 2, 'tid': 0, 'spec': None, 'result': {'loss': 5.246095087868275, 'status': 'ok', 'accuracy': 0.26296596434359804, 'avg_class_accuracy': 0.16443023255813954, 'eval_time': 1584359059.7268002, 'RunParams': {'optimizer': 'adam', 'batch_size': 4, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 0, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [0]}, 'vals': {'batch_size': [1]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 11, 40, 54, 978000), 'refresh_time': datetime.datetime(2020, 3, 16, 11, 44, 19, 776000)}
# {'state': 2, 'tid': 1, 'spec': None, 'result': {'loss': 1.2823111887102003, 'status': 'ok', 'accuracy': 0.6112012987012987, 'avg_class_accuracy': 0.5157666903970891, 'eval_time': 1584359171.8281198, 'RunParams': {'optimizer': 'adam', 'batch_size': 16, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 1, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [1]}, 'vals': {'batch_size': [3]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 11, 44, 19, 778000), 'refresh_time': datetime.datetime(2020, 3, 16, 11, 46, 11, 884000)}
# Written trials on run 1.
# HyperOpt batch size selected:4
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#   0% 0/2 [00:00<?, ?it/s, best loss: ?]2020-03-16 11:46:16.230404: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:46:16.231243: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-03-16 11:46:16.231341: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-16 11:46:16.231412: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-16 11:46:16.231464: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-16 11:46:16.231500: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-16 11:46:16.231527: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-16 11:46:16.231553: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-16 11:46:16.231581: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-16 11:46:16.231682: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:46:16.232544: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:46:16.233583: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-16 11:46:16.233693: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-16 11:46:16.233714: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-16 11:46:16.233726: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-16 11:46:16.233863: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:46:16.234733: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:46:16.235541: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# 2020-03-16 11:46:17.036321: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
# mean loss: 4.242338
# accuracy: 0.081311
# ----1-----
# mean loss: 3.457962
# accuracy: 0.130371
# ----2-----
# mean loss: 3.285025
# accuracy: 0.149902
# ----3-----
# mean loss: 3.362490
# accuracy: 0.115723
# ----4-----
# mean loss: 3.376034
# accuracy: 0.117676
# ----0-----
# ----1-----
# eval mean loss: 3.181223
# eval accuracy: 0.129254
# eval avg class acc: 0.079750
# --- Total running time for EPOCH 000 : 0:01:43.174358 ---
# Model saved in file: log/hyperopt88/1/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 3.250491
# accuracy: 0.144043
# ----1-----
# mean loss: 3.184214
# accuracy: 0.148926
# ----2-----
# mean loss: 3.209423
# accuracy: 0.135254
# ----3-----
# mean loss: 3.013809
# accuracy: 0.192383
# ----4-----
# mean loss: 3.031702
# accuracy: 0.172937
# ----0-----
# ----1-----
# eval mean loss: 4.244507
# eval accuracy: 0.197731
# eval avg class acc: 0.132000
# --- Total running time for EPOCH 001 : 0:01:41.064430 ---
# --- Total running time for MAIN : 0:03:30.709255 ---
# HyperOpt batch size selected:32
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#  50% 1/2 [03:30<03:30, 210.73s/it, best loss: 1.2823111887102003]2020-03-16 11:49:46.847024: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:49:46.847959: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-03-16 11:49:46.848097: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-16 11:49:46.848141: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-16 11:49:46.848182: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-16 11:49:46.848218: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-16 11:49:46.848255: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-16 11:49:46.848292: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-16 11:49:46.848331: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-16 11:49:46.848461: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:49:46.849350: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:49:46.850179: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-16 11:49:46.850244: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-16 11:49:46.850267: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-16 11:49:46.850283: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-16 11:49:46.850446: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:49:46.851346: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:49:46.852177: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# 2020-03-16 11:49:47.649588: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
# mean loss: 3.709306
# accuracy: 0.228516
# ----1-----
# mean loss: 2.731414
# accuracy: 0.323242
# ----2-----
# mean loss: 2.383605
# accuracy: 0.391602
# ----3-----
# mean loss: 1.982342
# accuracy: 0.488281
# ----4-----
# mean loss: 1.789688
# accuracy: 0.522059
# ----0-----
# ----1-----
# eval mean loss: 1.823923
# eval accuracy: 0.504464
# eval avg class acc: 0.434636
# --- Total running time for EPOCH 000 : 0:00:47.148924 ---
# Model saved in file: log/hyperopt88/1/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 1.666124
# accuracy: 0.545343
# ----1-----
# mean loss: 1.672509
# accuracy: 0.528809
# ----2-----
# mean loss: 1.583076
# accuracy: 0.567383
# ----3-----
# mean loss: 1.517818
# accuracy: 0.567383
# ----4-----
# mean loss: 1.436762
# accuracy: 0.583008
# ----0-----
# ----1-----
# eval mean loss: 1.232205
# eval accuracy: 0.613231
# eval avg class acc: 0.516012
# --- Total running time for EPOCH 001 : 0:00:45.462868 ---
# --- Total running time for MAIN : 0:01:38.840547 ---
# 100% 2/2 [05:09<00:00, 177.17s/it, best loss: 1.2322049922757334]
# Run 2 - Best param found:{'batch_size': 4}
# {'state': 2, 'tid': 0, 'spec': None, 'result': {'loss': 5.246095087868275, 'status': 'ok', 'accuracy': 0.26296596434359804, 'avg_class_accuracy': 0.16443023255813954, 'eval_time': 1584359059.7268002, 'RunParams': {'optimizer': 'adam', 'batch_size': 4, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 0, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [0]}, 'vals': {'batch_size': [1]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 11, 40, 54, 978000), 'refresh_time': datetime.datetime(2020, 3, 16, 11, 44, 19, 776000)}
# {'state': 2, 'tid': 1, 'spec': None, 'result': {'loss': 1.2823111887102003, 'status': 'ok', 'accuracy': 0.6112012987012987, 'avg_class_accuracy': 0.5157666903970891, 'eval_time': 1584359171.8281198, 'RunParams': {'optimizer': 'adam', 'batch_size': 16, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 1, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [1]}, 'vals': {'batch_size': [3]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 11, 44, 19, 778000), 'refresh_time': datetime.datetime(2020, 3, 16, 11, 46, 11, 884000)}
# {'state': 2, 'tid': 2, 'spec': None, 'result': {'loss': 4.244506696248171, 'status': 'ok', 'accuracy': 0.19773095623987033, 'avg_class_accuracy': 0.132, 'eval_time': 1584359382.5804002, 'RunParams': {'optimizer': 'adam', 'batch_size': 4, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 2, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [2]}, 'vals': {'batch_size': [1]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 11, 46, 11, 904000), 'refresh_time': datetime.datetime(2020, 3, 16, 11, 49, 42, 635000)}
# {'state': 2, 'tid': 3, 'spec': None, 'result': {'loss': 1.2322049922757334, 'status': 'ok', 'accuracy': 0.6132305194805194, 'avg_class_accuracy': 0.5160118352485462, 'eval_time': 1584359481.4450324, 'RunParams': {'optimizer': 'adam', 'batch_size': 32, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 3, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [3]}, 'vals': {'batch_size': [4]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 11, 49, 42, 638000), 'refresh_time': datetime.datetime(2020, 3, 16, 11, 51, 21, 495000)}
# Written trials on run 2.

# %%
#os.chdir('/content/drive/My Drive/GitHub/PointnetEnhanced/pointnet/log/hyperopt')
#!pip install --upgrade hyperopt
#from __future__ import absolute_import
import os
import pickle
from hyperopt import Trials
os.chdir('/content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/log/hyperopt/1')
# !ls

trials = Trials()
LOG_DIR = ""
trialFilePath = os.path.join(LOG_DIR, "trials.p")
if os.path.exists(trialFilePath):
    trials = pickle.load(open(trialFilePath, "rb"))
    print ("Trials loaded.")

import json
import pickle
#WRITER = open("test.txt", "wb")
for trial in trials.results:
    print (trial)

print (trials.idxs_vals[0])
  
import pandas as pd
# Dataframe of results from optimization
tpe_results = pd.DataFrame({'batch size': [x['RunParams']['batch_size'] for x in trials.results],
                            'loss': [x['loss'] for x in trials.results],
                            'accuracy': [x['accuracy'] for x in trials.results] 
                            })
                            
tpe_results.head()
# Out:
# checkpoint     model.ckpt.data-00000-of-00001  model.ckpt.meta	test   train.py
# log_train.txt  model.ckpt.index		       pointnet_cls.py	train  trials.p
# Trials loaded.
# {'loss': 1.160251766249731, 'status': 'ok', 'accuracy': 0.6554383116883117, 'avg_class_accuracy': 0.5793263484393052, 'eval_time': 1583753076.3301764, 'RunParams': {'optimizer': 'adam', 'batch_size': 16, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 3}}
# {'loss': 1.3395599972505075, 'status': 'ok', 'accuracy': 0.5949675324675324, 'avg_class_accuracy': 0.5010895751535287, 'eval_time': 1583753775.2543623, 'RunParams': {'optimizer': 'adam', 'batch_size': 8, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 3}}
# {'loss': 1.229252468649443, 'status': 'ok', 'accuracy': 0.6282467532467533, 'avg_class_accuracy': 0.5495627417986222, 'eval_time': 1583754428.544316, 'RunParams': {'optimizer': 'adam', 'batch_size': 16, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 3}}
# {'loss': 1.4733369370753115, 'status': 'ok', 'accuracy': 0.6026785714285714, 'avg_class_accuracy': 0.5212600650549155, 'eval_time': 1583755111.6566696, 'RunParams': {'optimizer': 'adam', 'batch_size': 8, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 3}}
# {'batch_size': [0, 1, 2, 3]}
#    batch size      loss  accuracy
# 0          16  1.160252  0.655438
# 1           8  1.339560  0.594968
# 2          16  1.229252  0.628247
# 3           8  1.473337  0.602679

# %%
import os
#os.chdir('/content/gdrive/My Drive/KE5208_Sense_Making/Code/pointnet00/')
os.chdir('/content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet')

#second run since first run was interrupted at EPOCH 119
# !python train.py --max_epoch=2 --run_mode='hyperopt' --log_dir="log/hyperopttiny" --max_eval=1  # --batch_size=16 #--log_dir="log"
# Out:
# Log dir:log/hyperopttiny already exists! creating a new one.
# New log dir:log/hyperopttiny/2
# 1:Starting the run with the mode:hyperopt
# Namespace(batch_size=32, decay_rate=0.7, decay_step=200000, gpu=0, learning_rate=0.001, log_dir='log/hyperopttiny', max_epoch=2, max_evals=1, max_trials=10, model='pointnet_cls', model_path='', momentum=0.9, mongo_mode=0, num_point=1024, optimizer='adam', run_mode='hyperopt', trials_path='')
#
# Starting hyperopt
# HyperOpt batch size selected:4
#   0% 0/1 [00:00<?, ?it/s, best loss: ?]WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/models/pointnet_cls.py:13: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#   0% 0/1 [00:00<?, ?it/s, best loss: ?]WARNING:tensorflow:From train.py:133: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From train.py:160: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/models/pointnet_cls.py:24: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:21: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:48: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:368: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:Variable += will be deprecated. Use variable.assign_add if you want assignment to the variable value or 'x = x + y' if you want a new python Tensor object.
# WARNING:tensorflow:Variable += will be deprecated. Use variable.assign_add if you want assignment to the variable value or 'x = x + y' if you want a new python Tensor object.
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:573: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From train.py:167: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From train.py:177: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From train.py:181: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From train.py:184: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From train.py:188: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-03-16 11:51:36.909321: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-03-16 11:51:36.909611: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x31f5100 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-03-16 11:51:36.909649: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-03-16 11:51:36.912663: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-03-16 11:51:37.025187: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:51:37.026316: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x31f52c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-03-16 11:51:37.026404: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-03-16 11:51:37.026688: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:51:37.027569: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-03-16 11:51:37.027908: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-16 11:51:37.029717: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-16 11:51:37.031552: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-16 11:51:37.031909: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-16 11:51:37.033596: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-16 11:51:37.034382: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-16 11:51:37.037665: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-16 11:51:37.037833: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:51:37.038809: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:51:37.039684: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-16 11:51:37.039769: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-16 11:51:37.041716: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-16 11:51:37.041757: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-16 11:51:37.041795: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-16 11:51:37.042057: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:51:37.043135: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:51:37.044095: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# WARNING:tensorflow:From train.py:201: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From train.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From train.py:210: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# 2020-03-16 11:51:37.584196: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
#   0% 0/1 [00:06<?, ?it/s, best loss: ?]2020-03-16 11:51:40.438248: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-16 11:51:40.721481: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# mean loss: 4.152444
# accuracy: 0.095215
# ----1-----
# mean loss: 3.440399
# accuracy: 0.126953
# ----2-----
# mean loss: 3.580074
# accuracy: 0.099609
# ----3-----
# mean loss: 3.387937
# accuracy: 0.117188
# ----4-----
# mean loss: 3.303240
# accuracy: 0.137743
# ----0-----
# ----1-----
# eval mean loss: 3.895374
# eval accuracy: 0.117099
# eval avg class acc: 0.081250
# --- Total running time for EPOCH 000 : 0:01:38.601629 ---
# Model saved in file: log/hyperopttiny/2/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 3.130255
# accuracy: 0.156738
# ----1-----
# mean loss: 3.078783
# accuracy: 0.161408
# ----2-----
# mean loss: 3.068623
# accuracy: 0.176758
# ----3-----
# mean loss: 3.142211
# accuracy: 0.168457
# ----4-----
# mean loss: 3.048661
# accuracy: 0.165527
# ----0-----
# ----1-----
# eval mean loss: 227.994491
# eval accuracy: 0.152755
# eval avg class acc: 0.098959
# --- Total running time for EPOCH 001 : 0:01:36.168483 ---
# --- Total running time for MAIN : 0:03:22.476193 ---
# 100% 1/1 [03:22<00:00, 202.50s/it, best loss: 227.99449132868304]
# Run 1 - Best param found:{'batch_size': 1}
# {'state': 2, 'tid': 0, 'spec': None, 'result': {'loss': 227.99449132868304, 'status': 'ok', 'accuracy': 0.1527552674230146, 'avg_class_accuracy': 0.0989593023255814, 'eval_time': 1584359694.3277092, 'RunParams': {'optimizer': 'adam', 'batch_size': 4, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 0, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [0]}, 'vals': {'batch_size': [1]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 11, 51, 31, 902000), 'refresh_time': datetime.datetime(2020, 3, 16, 11, 54, 54, 400000)}
# Written trials on run 1.
# HyperOpt batch size selected:8
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#   0% 0/1 [00:00<?, ?it/s, best loss: ?]2020-03-16 11:54:58.527815: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:54:58.528676: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-03-16 11:54:58.528796: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-16 11:54:58.528849: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-16 11:54:58.528901: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-16 11:54:58.528942: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-16 11:54:58.528985: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-16 11:54:58.529035: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-16 11:54:58.529084: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-16 11:54:58.529284: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:54:58.530757: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:54:58.531533: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-16 11:54:58.531589: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-16 11:54:58.531603: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-16 11:54:58.531613: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-16 11:54:58.531833: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:54:58.532948: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:54:58.533779: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# 2020-03-16 11:54:59.165871: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
# mean loss: 3.791816
# accuracy: 0.150391
# ----1-----
# mean loss: 3.251716
# accuracy: 0.188477
# ----2-----
# mean loss: 3.032776
# accuracy: 0.219727
# ----3-----
# mean loss: 2.741719
# accuracy: 0.265137
# ----4-----
# mean loss: 2.531389
# accuracy: 0.297937
# ----0-----
# ----1-----
# eval mean loss: 2.221484
# eval accuracy: 0.400974
# eval avg class acc: 0.307441
# --- Total running time for EPOCH 000 : 0:01:06.120375 ---
# Model saved in file: log/hyperopttiny/2/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 2.378316
# accuracy: 0.341309
# ----1-----
# mean loss: 2.249819
# accuracy: 0.361044
# ----2-----
# mean loss: 2.200656
# accuracy: 0.363281
# ----3-----
# mean loss: 2.021776
# accuracy: 0.407227
# ----4-----
# mean loss: 1.922357
# accuracy: 0.442383
# ----0-----
# ----1-----
# eval mean loss: 1.565986
# eval accuracy: 0.518669
# eval avg class acc: 0.434360
# --- Total running time for EPOCH 001 : 0:01:04.166497 ---
# --- Total running time for MAIN : 0:02:16.222545 ---
# 100% 1/1 [02:16<00:00, 136.24s/it, best loss: 1.5659855313889393]
# Run 2 - Best param found:{'batch_size': 2}
# {'state': 2, 'tid': 0, 'spec': None, 'result': {'loss': 227.99449132868304, 'status': 'ok', 'accuracy': 0.1527552674230146, 'avg_class_accuracy': 0.0989593023255814, 'eval_time': 1584359694.3277092, 'RunParams': {'optimizer': 'adam', 'batch_size': 4, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 0, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [0]}, 'vals': {'batch_size': [1]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 11, 51, 31, 902000), 'refresh_time': datetime.datetime(2020, 3, 16, 11, 54, 54, 400000)}
# {'state': 2, 'tid': 1, 'spec': None, 'result': {'loss': 1.5659855313889393, 'status': 'ok', 'accuracy': 0.5186688311688312, 'avg_class_accuracy': 0.43436045073420493, 'eval_time': 1584359830.6148405, 'RunParams': {'optimizer': 'adam', 'batch_size': 8, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 1, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [1]}, 'vals': {'batch_size': [2]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 11, 54, 54, 422000), 'refresh_time': datetime.datetime(2020, 3, 16, 11, 57, 10, 665000)}
# Written trials on run 2.
# HyperOpt batch size selected:16
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#   0% 0/1 [00:00<?, ?it/s, best loss: ?]2020-03-16 11:57:14.898408: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:57:14.899259: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-03-16 11:57:14.899375: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-16 11:57:14.899412: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-16 11:57:14.899443: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-16 11:57:14.899473: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-16 11:57:14.899502: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-16 11:57:14.899531: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-16 11:57:14.899560: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-16 11:57:14.899667: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:57:14.900616: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:57:14.901481: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-16 11:57:14.901536: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-16 11:57:14.901555: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-16 11:57:14.901568: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-16 11:57:14.901704: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:57:14.902604: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:57:14.903517: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# 2020-03-16 11:57:15.538422: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
# mean loss: 3.802240
# accuracy: 0.161408
# ----1-----
# mean loss: 3.005952
# accuracy: 0.230469
# ----2-----
# mean loss: 2.848279
# accuracy: 0.250977
# ----3-----
# mean loss: 2.628157
# accuracy: 0.290039
# ----4-----
# mean loss: 2.308061
# accuracy: 0.360352
# ----0-----
# ----1-----
# eval mean loss: 2.108651
# eval accuracy: 0.365666
# eval avg class acc: 0.291382
# --- Total running time for EPOCH 000 : 0:00:52.637716 ---
# Model saved in file: log/hyperopttiny/2/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 2.128208
# accuracy: 0.388672
# ----1-----
# mean loss: 2.123781
# accuracy: 0.394043
# ----2-----
# mean loss: 1.883462
# accuracy: 0.454102
# ----3-----
# mean loss: 1.716337
# accuracy: 0.497573
# ----4-----
# mean loss: 1.636634
# accuracy: 0.515625
# ----0-----
# ----1-----
# eval mean loss: 1.442773
# eval accuracy: 0.556412
# eval avg class acc: 0.464434
# --- Total running time for EPOCH 001 : 0:00:50.943666 ---
# --- Total running time for MAIN : 0:01:49.561118 ---
# 100% 1/1 [01:49<00:00, 109.60s/it, best loss: 1.4427733556790785]
# Run 3 - Best param found:{'batch_size': 3}
# {'state': 2, 'tid': 0, 'spec': None, 'result': {'loss': 227.99449132868304, 'status': 'ok', 'accuracy': 0.1527552674230146, 'avg_class_accuracy': 0.0989593023255814, 'eval_time': 1584359694.3277092, 'RunParams': {'optimizer': 'adam', 'batch_size': 4, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 0, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [0]}, 'vals': {'batch_size': [1]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 11, 51, 31, 902000), 'refresh_time': datetime.datetime(2020, 3, 16, 11, 54, 54, 400000)}
# {'state': 2, 'tid': 1, 'spec': None, 'result': {'loss': 1.5659855313889393, 'status': 'ok', 'accuracy': 0.5186688311688312, 'avg_class_accuracy': 0.43436045073420493, 'eval_time': 1584359830.6148405, 'RunParams': {'optimizer': 'adam', 'batch_size': 8, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 1, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [1]}, 'vals': {'batch_size': [2]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 11, 54, 54, 422000), 'refresh_time': datetime.datetime(2020, 3, 16, 11, 57, 10, 665000)}
# {'state': 2, 'tid': 2, 'spec': None, 'result': {'loss': 1.4427733556790785, 'status': 'ok', 'accuracy': 0.5564123376623377, 'avg_class_accuracy': 0.46443422118671285, 'eval_time': 1584359940.2268653, 'RunParams': {'optimizer': 'adam', 'batch_size': 16, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 2, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [2]}, 'vals': {'batch_size': [3]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 11, 57, 10, 682000), 'refresh_time': datetime.datetime(2020, 3, 16, 11, 59, 0, 278000)}
# Written trials on run 3.
# HyperOpt batch size selected:32
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#   0% 0/1 [00:00<?, ?it/s, best loss: ?]2020-03-16 11:59:04.432915: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:59:04.433686: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-03-16 11:59:04.433762: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-16 11:59:04.433791: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-16 11:59:04.433815: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-16 11:59:04.433838: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-16 11:59:04.433860: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-16 11:59:04.433881: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-16 11:59:04.433904: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-16 11:59:04.433984: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:59:04.434873: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:59:04.435560: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-16 11:59:04.435610: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-16 11:59:04.435629: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-16 11:59:04.435639: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-16 11:59:04.435782: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:59:04.436541: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 11:59:04.437235: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# 2020-03-16 11:59:05.189037: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
# mean loss: 3.953060
# accuracy: 0.178711
# ----1-----
# mean loss: 2.872725
# accuracy: 0.298828
# ----2-----
# mean loss: 2.324689
# accuracy: 0.406250
# ----3-----
# mean loss: 2.100528
# accuracy: 0.428223
# ----4-----
# mean loss: 1.750756
# accuracy: 0.517578
# ----0-----
# ----1-----
# eval mean loss: 1.786952
# eval accuracy: 0.463068
# eval avg class acc: 0.400898
# --- Total running time for EPOCH 000 : 0:00:46.523613 ---
# Model saved in file: log/hyperopttiny/2/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 1.725417
# accuracy: 0.522461
# ----1-----
# mean loss: 1.814777
# accuracy: 0.506836
# ----2-----
# mean loss: 1.695481
# accuracy: 0.540527
# ----3-----
# mean loss: 1.442655
# accuracy: 0.581055
# ----4-----
# mean loss: 1.353259
# accuracy: 0.598652
# ----0-----
# ----1-----
# eval mean loss: 1.223947
# eval accuracy: 0.643669
# eval avg class acc: 0.541515
# --- Total running time for EPOCH 001 : 0:00:44.891489 ---
# --- Total running time for MAIN : 0:01:37.619896 ---
# 100% 1/1 [01:37<00:00, 97.64s/it, best loss: 1.2239466572736766]
# Run 4 - Best param found:{'batch_size': 4}
# {'state': 2, 'tid': 0, 'spec': None, 'result': {'loss': 227.99449132868304, 'status': 'ok', 'accuracy': 0.1527552674230146, 'avg_class_accuracy': 0.0989593023255814, 'eval_time': 1584359694.3277092, 'RunParams': {'optimizer': 'adam', 'batch_size': 4, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 0, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [0]}, 'vals': {'batch_size': [1]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 11, 51, 31, 902000), 'refresh_time': datetime.datetime(2020, 3, 16, 11, 54, 54, 400000)}
# {'state': 2, 'tid': 1, 'spec': None, 'result': {'loss': 1.5659855313889393, 'status': 'ok', 'accuracy': 0.5186688311688312, 'avg_class_accuracy': 0.43436045073420493, 'eval_time': 1584359830.6148405, 'RunParams': {'optimizer': 'adam', 'batch_size': 8, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 1, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [1]}, 'vals': {'batch_size': [2]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 11, 54, 54, 422000), 'refresh_time': datetime.datetime(2020, 3, 16, 11, 57, 10, 665000)}
# {'state': 2, 'tid': 2, 'spec': None, 'result': {'loss': 1.4427733556790785, 'status': 'ok', 'accuracy': 0.5564123376623377, 'avg_class_accuracy': 0.46443422118671285, 'eval_time': 1584359940.2268653, 'RunParams': {'optimizer': 'adam', 'batch_size': 16, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 2, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [2]}, 'vals': {'batch_size': [3]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 11, 57, 10, 682000), 'refresh_time': datetime.datetime(2020, 3, 16, 11, 59, 0, 278000)}
# {'state': 2, 'tid': 3, 'spec': None, 'result': {'loss': 1.2239466572736766, 'status': 'ok', 'accuracy': 0.6436688311688312, 'avg_class_accuracy': 0.5415148267199762, 'eval_time': 1584360037.8788638, 'RunParams': {'optimizer': 'adam', 'batch_size': 32, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 3, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [3]}, 'vals': {'batch_size': [4]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 11, 59, 0, 298000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 0, 37, 936000)}
# Written trials on run 4.
# HyperOpt batch size selected:16
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#   0% 0/1 [00:00<?, ?it/s, best loss: ?]2020-03-16 12:00:41.738790: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:00:41.739669: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-03-16 12:00:41.739855: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-16 12:00:41.739904: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-16 12:00:41.739942: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-16 12:00:41.739976: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-16 12:00:41.740010: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-16 12:00:41.740043: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-16 12:00:41.740079: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-16 12:00:41.740212: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:00:41.741156: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:00:41.741891: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-16 12:00:41.741978: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-16 12:00:41.741999: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-16 12:00:41.742013: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-16 12:00:41.742242: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:00:41.743281: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:00:41.744071: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# 2020-03-16 12:00:42.439250: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
# mean loss: 3.781355
# accuracy: 0.165039
# ----1-----
# mean loss: 3.024219
# accuracy: 0.239078
# ----2-----
# mean loss: 2.698717
# accuracy: 0.292480
# ----3-----
# mean loss: 2.407985
# accuracy: 0.331055
# ----4-----
# mean loss: 2.311871
# accuracy: 0.349121
# ----0-----
# ----1-----
# eval mean loss: 2.170900
# eval accuracy: 0.359172
# eval avg class acc: 0.291130
# --- Total running time for EPOCH 000 : 0:00:52.513670 ---
# Model saved in file: log/hyperopttiny/2/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 2.000707
# accuracy: 0.402306
# ----1-----
# mean loss: 1.877127
# accuracy: 0.445801
# ----2-----
# mean loss: 1.795761
# accuracy: 0.461914
# ----3-----
# mean loss: 1.776608
# accuracy: 0.469238
# ----4-----
# mean loss: 1.627574
# accuracy: 0.500488
# ----0-----
# ----1-----
# eval mean loss: 1.366844
# eval accuracy: 0.572240
# eval avg class acc: 0.472568
# --- Total running time for EPOCH 001 : 0:00:51.366041 ---
# --- Total running time for MAIN : 0:01:49.529748 ---
# 100% 1/1 [01:49<00:00, 109.55s/it, best loss: 1.2239466572736766]
# Run 5 - Best param found:{'batch_size': 4}
# {'state': 2, 'tid': 0, 'spec': None, 'result': {'loss': 227.99449132868304, 'status': 'ok', 'accuracy': 0.1527552674230146, 'avg_class_accuracy': 0.0989593023255814, 'eval_time': 1584359694.3277092, 'RunParams': {'optimizer': 'adam', 'batch_size': 4, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 0, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [0]}, 'vals': {'batch_size': [1]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 11, 51, 31, 902000), 'refresh_time': datetime.datetime(2020, 3, 16, 11, 54, 54, 400000)}
# {'state': 2, 'tid': 1, 'spec': None, 'result': {'loss': 1.5659855313889393, 'status': 'ok', 'accuracy': 0.5186688311688312, 'avg_class_accuracy': 0.43436045073420493, 'eval_time': 1584359830.6148405, 'RunParams': {'optimizer': 'adam', 'batch_size': 8, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 1, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [1]}, 'vals': {'batch_size': [2]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 11, 54, 54, 422000), 'refresh_time': datetime.datetime(2020, 3, 16, 11, 57, 10, 665000)}
# {'state': 2, 'tid': 2, 'spec': None, 'result': {'loss': 1.4427733556790785, 'status': 'ok', 'accuracy': 0.5564123376623377, 'avg_class_accuracy': 0.46443422118671285, 'eval_time': 1584359940.2268653, 'RunParams': {'optimizer': 'adam', 'batch_size': 16, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 2, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [2]}, 'vals': {'batch_size': [3]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 11, 57, 10, 682000), 'refresh_time': datetime.datetime(2020, 3, 16, 11, 59, 0, 278000)}
# {'state': 2, 'tid': 3, 'spec': None, 'result': {'loss': 1.2239466572736766, 'status': 'ok', 'accuracy': 0.6436688311688312, 'avg_class_accuracy': 0.5415148267199762, 'eval_time': 1584360037.8788638, 'RunParams': {'optimizer': 'adam', 'batch_size': 32, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 3, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [3]}, 'vals': {'batch_size': [4]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 11, 59, 0, 298000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 0, 37, 936000)}
# {'state': 2, 'tid': 4, 'spec': None, 'result': {'loss': 1.3668441087394565, 'status': 'ok', 'accuracy': 0.5722402597402597, 'avg_class_accuracy': 0.47256800803478544, 'eval_time': 1584360147.4518106, 'RunParams': {'optimizer': 'adam', 'batch_size': 16, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 4, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [4]}, 'vals': {'batch_size': [3]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 0, 37, 956000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 2, 27, 502000)}
# Written trials on run 5.
# HyperOpt batch size selected:4
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#   0% 0/1 [00:00<?, ?it/s, best loss: ?]2020-03-16 12:02:31.581753: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:02:31.582701: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-03-16 12:02:31.582806: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-16 12:02:31.582855: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-16 12:02:31.582926: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-16 12:02:31.582974: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-16 12:02:31.583020: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-16 12:02:31.583069: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-16 12:02:31.583119: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-16 12:02:31.583279: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:02:31.584459: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:02:31.585289: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-16 12:02:31.585431: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-16 12:02:31.585541: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-16 12:02:31.585562: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-16 12:02:31.585848: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:02:31.586767: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:02:31.587605: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# 2020-03-16 12:02:32.299120: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
# mean loss: 4.119861
# accuracy: 0.093750
# ----1-----
# mean loss: 3.551519
# accuracy: 0.102539
# ----2-----
# mean loss: 3.378747
# accuracy: 0.150391
# ----3-----
# mean loss: 3.301142
# accuracy: 0.129248
# ----4-----
# mean loss: 3.235392
# accuracy: 0.145508
# ----0-----
# ----1-----
# eval mean loss: 16.011166
# eval accuracy: 0.124392
# eval avg class acc: 0.078360
# --- Total running time for EPOCH 000 : 0:01:34.293850 ---
# Model saved in file: log/hyperopttiny/2/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 3.168688
# accuracy: 0.158203
# ----1-----
# mean loss: 3.037371
# accuracy: 0.185547
# ----2-----
# mean loss: 3.008616
# accuracy: 0.185547
# ----3-----
# mean loss: 2.876318
# accuracy: 0.220267
# ----4-----
# mean loss: 2.815037
# accuracy: 0.231934
# ----0-----
# ----1-----
# eval mean loss: 2.963705
# eval accuracy: 0.248379
# eval avg class acc: 0.189698
# --- Total running time for EPOCH 001 : 0:01:31.682233 ---
# --- Total running time for MAIN : 0:03:11.952639 ---
# 100% 1/1 [03:11<00:00, 191.97s/it, best loss: 1.2239466572736766]
# Run 6 - Best param found:{'batch_size': 4}
# ...
# {'state': 2, 'tid': 3, 'spec': None, 'result': {'loss': 1.2239466572736766, 'status': 'ok', 'accuracy': 0.6436688311688312, 'avg_class_accuracy': 0.5415148267199762, 'eval_time': 1584360037.8788638, 'RunParams': {'optimizer': 'adam', 'batch_size': 32, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 3, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [3]}, 'vals': {'batch_size': [4]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 11, 59, 0, 298000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 0, 37, 936000)}
# {'state': 2, 'tid': 4, 'spec': None, 'result': {'loss': 1.3668441087394565, 'status': 'ok', 'accuracy': 0.5722402597402597, 'avg_class_accuracy': 0.47256800803478544, 'eval_time': 1584360147.4518106, 'RunParams': {'optimizer': 'adam', 'batch_size': 16, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 4, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [4]}, 'vals': {'batch_size': [3]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 0, 37, 956000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 2, 27, 502000)}
# {'state': 2, 'tid': 5, 'spec': None, 'result': {'loss': 2.9637047297757486, 'status': 'ok', 'accuracy': 0.24837925445705025, 'avg_class_accuracy': 0.1896976744186047, 'eval_time': 1584360339.4641836, 'RunParams': {'optimizer': 'adam', 'batch_size': 4, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 5, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [5]}, 'vals': {'batch_size': [1]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 2, 27, 546000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 5, 39, 514000)}
# {'state': 2, 'tid': 6, 'spec': None, 'result': {'loss': 1.9309080357288386, 'status': 'ok', 'accuracy': 0.41233766233766234, 'avg_class_accuracy': 0.36509936575052854, 'eval_time': 1584360474.5532563, 'RunParams': {'optimizer': 'adam', 'batch_size': 8, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 6, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [6]}, 'vals': {'batch_size': [2]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 5, 39, 535000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 7, 54, 607000)}
# {'state': 2, 'tid': 7, 'spec': None, 'result': {'loss': 2.973125581223536, 'status': 'ok', 'accuracy': 0.19611021069692058, 'avg_class_accuracy': 0.12400000000000003, 'eval_time': 1584360664.4517992, 'RunParams': {'optimizer': 'adam', 'batch_size': 4, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 7, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [7]}, 'vals': {'batch_size': [1]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 7, 54, 634000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 11, 4, 511000)}
# {'state': 2, 'tid': 8, 'spec': None, 'result': {'loss': 200.28977913388943, 'status': 'ok', 'accuracy': 0.06361426256077796, 'avg_class_accuracy': 0.03925, 'eval_time': 1584360989.0365577, 'RunParams': {'optimizer': 'adam', 'batch_size': 2, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 8, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [8]}, 'vals': {'batch_size': [0]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 11, 4, 554000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 16, 29, 87000)}
# Written trials on run 9.
# HyperOpt batch size selected:32
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#   0% 0/1 [00:00<?, ?it/s, best loss: ?]2020-03-16 12:16:33.010895: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:16:33.011649: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-03-16 12:16:33.011741: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-16 12:16:33.011795: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-16 12:16:33.011842: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-16 12:16:33.011898: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-16 12:16:33.011939: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-16 12:16:33.011977: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-16 12:16:33.012046: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-16 12:16:33.012174: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:16:33.012890: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:16:33.013490: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-16 12:16:33.013540: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-16 12:16:33.013562: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-16 12:16:33.013574: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-16 12:16:33.013690: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:16:33.014480: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:16:33.015093: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# 2020-03-16 12:16:33.677068: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
# mean loss: 3.799301
# accuracy: 0.207031
# ----1-----
# mean loss: 2.817332
# accuracy: 0.302083
# ----2-----
# mean loss: 2.366172
# accuracy: 0.383789
# ----3-----
# mean loss: 2.002013
# accuracy: 0.472656
# ----4-----
# mean loss: 1.844481
# accuracy: 0.502441
# ----0-----
# ----1-----
# eval mean loss: 1.868565
# eval accuracy: 0.491477
# eval avg class acc: 0.393206
# --- Total running time for EPOCH 000 : 0:00:46.440367 ---
# Model saved in file: log/hyperopttiny/2/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 1.952881
# accuracy: 0.475586
# ----1-----
# mean loss: 1.712464
# accuracy: 0.520020
# ----2-----
# mean loss: 1.432013
# accuracy: 0.596814
# ----3-----
# mean loss: 1.443133
# accuracy: 0.598633
# ----4-----
# mean loss: 1.382714
# accuracy: 0.609863
# ----0-----
# ----1-----
# eval mean loss: 1.235318
# eval accuracy: 0.651380
# eval avg class acc: 0.552248
# --- Total running time for EPOCH 001 : 0:00:44.767790 ---
# --- Total running time for MAIN : 0:01:36.923114 ---
# 100% 1/1 [01:36<00:00, 96.94s/it, best loss: 1.2239466572736766]
# Run 10 - Best param found:{'batch_size': 4}
# {'state': 2, 'tid': 0, 'spec': None, 'result': {'loss': 227.99449132868304, 'status': 'ok', 'accuracy': 0.1527552674230146, 'avg_class_accuracy': 0.0989593023255814, 'eval_time': 1584359694.3277092, 'RunParams': {'optimizer': 'adam', 'batch_size': 4, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 0, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [0]}, 'vals': {'batch_size': [1]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 11, 51, 31, 902000), 'refresh_time': datetime.datetime(2020, 3, 16, 11, 54, 54, 400000)}
# {'state': 2, 'tid': 1, 'spec': None, 'result': {'loss': 1.5659855313889393, 'status': 'ok', 'accuracy': 0.5186688311688312, 'avg_class_accuracy': 0.43436045073420493, 'eval_time': 1584359830.6148405, 'RunParams': {'optimizer': 'adam', 'batch_size': 8, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 1, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [1]}, 'vals': {'batch_size': [2]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 11, 54, 54, 422000), 'refresh_time': datetime.datetime(2020, 3, 16, 11, 57, 10, 665000)}
# {'state': 2, 'tid': 2, 'spec': None, 'result': {'loss': 1.4427733556790785, 'status': 'ok', 'accuracy': 0.5564123376623377, 'avg_class_accuracy': 0.46443422118671285, 'eval_time': 1584359940.2268653, 'RunParams': {'optimizer': 'adam', 'batch_size': 16, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 2, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [2]}, 'vals': {'batch_size': [3]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 11, 57, 10, 682000), 'refresh_time': datetime.datetime(2020, 3, 16, 11, 59, 0, 278000)}
# {'state': 2, 'tid': 3, 'spec': None, 'result': {'loss': 1.2239466572736766, 'status': 'ok', 'accuracy': 0.6436688311688312, 'avg_class_accuracy': 0.5415148267199762, 'eval_time': 1584360037.8788638, 'RunParams': {'optimizer': 'adam', 'batch_size': 32, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 3, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [3]}, 'vals': {'batch_size': [4]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 11, 59, 0, 298000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 0, 37, 936000)}
# {'state': 2, 'tid': 4, 'spec': None, 'result': {'loss': 1.3668441087394565, 'status': 'ok', 'accuracy': 0.5722402597402597, 'avg_class_accuracy': 0.47256800803478544, 'eval_time': 1584360147.4518106, 'RunParams': {'optimizer': 'adam', 'batch_size': 16, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 4, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [4]}, 'vals': {'batch_size': [3]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 0, 37, 956000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 2, 27, 502000)}
# {'state': 2, 'tid': 5, 'spec': None, 'result': {'loss': 2.9637047297757486, 'status': 'ok', 'accuracy': 0.24837925445705025, 'avg_class_accuracy': 0.1896976744186047, 'eval_time': 1584360339.4641836, 'RunParams': {'optimizer': 'adam', 'batch_size': 4, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 5, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [5]}, 'vals': {'batch_size': [1]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 2, 27, 546000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 5, 39, 514000)}
# {'state': 2, 'tid': 6, 'spec': None, 'result': {'loss': 1.9309080357288386, 'status': 'ok', 'accuracy': 0.41233766233766234, 'avg_class_accuracy': 0.36509936575052854, 'eval_time': 1584360474.5532563, 'RunParams': {'optimizer': 'adam', 'batch_size': 8, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 6, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [6]}, 'vals': {'batch_size': [2]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 5, 39, 535000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 7, 54, 607000)}
# {'state': 2, 'tid': 7, 'spec': None, 'result': {'loss': 2.973125581223536, 'status': 'ok', 'accuracy': 0.19611021069692058, 'avg_class_accuracy': 0.12400000000000003, 'eval_time': 1584360664.4517992, 'RunParams': {'optimizer': 'adam', 'batch_size': 4, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 7, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [7]}, 'vals': {'batch_size': [1]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 7, 54, 634000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 11, 4, 511000)}
# {'state': 2, 'tid': 8, 'spec': None, 'result': {'loss': 200.28977913388943, 'status': 'ok', 'accuracy': 0.06361426256077796, 'avg_class_accuracy': 0.03925, 'eval_time': 1584360989.0365577, 'RunParams': {'optimizer': 'adam', 'batch_size': 2, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 8, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [8]}, 'vals': {'batch_size': [0]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 11, 4, 554000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 16, 29, 87000)}
# {'state': 2, 'tid': 9, 'spec': None, 'result': {'loss': 1.235317517410625, 'status': 'ok', 'accuracy': 0.6513798701298701, 'avg_class_accuracy': 0.5522478882321076, 'eval_time': 1584361086.0028303, 'RunParams': {'optimizer': 'adam', 'batch_size': 32, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 9, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [9]}, 'vals': {'batch_size': [4]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 16, 29, 118000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 18, 6, 57000)}
# Written trials on run 10.

# %%
import os
#os.chdir('/content/gdrive/My Drive/KE5208_Sense_Making/Code/pointnet00/')
os.chdir('/content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/')

#second run since first run was interrupted at EPOCH 119
# !python train.py --max_epoch=2 --run_mode='hyperopt' --log_dir="log/hyperopttiny" --max_eval=2  # --batch_size=16 #--log_dir="log"
# Out:
# Log dir:log/hyperopttiny already exists! creating a new one.
# New log dir:log/hyperopttiny/3
# 1:Starting the run with the mode:hyperopt
# Namespace(batch_size=32, decay_rate=0.7, decay_step=200000, gpu=0, learning_rate=0.001, log_dir='log/hyperopttiny', max_epoch=2, max_evals=2, max_trials=10, model='pointnet_cls', model_path='', momentum=0.9, mongo_mode=0, num_point=1024, optimizer='adam', run_mode='hyperopt', trials_path='')
#
# Starting hyperopt
# HyperOpt batch size selected:32
#   0% 0/2 [00:00<?, ?it/s, best loss: ?]WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/models/pointnet_cls.py:13: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#   0% 0/2 [00:00<?, ?it/s, best loss: ?]WARNING:tensorflow:From train.py:133: The name tf.train.exponential_decay is deprecated. Please use tf.compat.v1.train.exponential_decay instead.
#
# WARNING:tensorflow:From train.py:160: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/models/pointnet_cls.py:24: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:21: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:48: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:368: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:Variable += will be deprecated. Use variable.assign_add if you want assignment to the variable value or 'x = x + y' if you want a new python Tensor object.
# WARNING:tensorflow:Variable += will be deprecated. Use variable.assign_add if you want assignment to the variable value or 'x = x + y' if you want a new python Tensor object.
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:573: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From train.py:167: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From train.py:177: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From train.py:181: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From train.py:184: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From train.py:188: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-03-16 12:18:16.090940: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-03-16 12:18:16.091146: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x31e7100 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-03-16 12:18:16.091178: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-03-16 12:18:16.093163: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-03-16 12:18:16.207131: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:18:16.208452: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x31e72c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-03-16 12:18:16.208498: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-03-16 12:18:16.208728: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:18:16.209685: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-03-16 12:18:16.210028: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-16 12:18:16.211667: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-16 12:18:16.213289: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-16 12:18:16.213675: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-16 12:18:16.215244: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-16 12:18:16.216181: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-16 12:18:16.219829: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-16 12:18:16.219981: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:18:16.220966: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:18:16.221822: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-16 12:18:16.221902: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-16 12:18:16.223560: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-16 12:18:16.223595: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-16 12:18:16.223612: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-16 12:18:16.223768: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:18:16.224717: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:18:16.225619: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# WARNING:tensorflow:From train.py:201: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From train.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From train.py:210: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# 2020-03-16 12:18:16.777044: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
#   0% 0/2 [00:06<?, ?it/s, best loss: ?]2020-03-16 12:18:19.342016: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-16 12:18:19.611570: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# mean loss: 3.858537
# accuracy: 0.199707
# ----1-----
# mean loss: 2.823956
# accuracy: 0.304199
# ----2-----
# mean loss: 2.270605
# accuracy: 0.406250
# ----3-----
# mean loss: 2.066544
# accuracy: 0.442402
# ----4-----
# mean loss: 1.974978
# accuracy: 0.463867
# ----0-----
# ----1-----
# eval mean loss: 1.821341
# eval accuracy: 0.493506
# eval avg class acc: 0.411010
# --- Total running time for EPOCH 000 : 0:00:47.391962 ---
# Model saved in file: log/hyperopttiny/3/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 1.824614
# accuracy: 0.496582
# ----1-----
# mean loss: 1.681997
# accuracy: 0.519043
# ----2-----
# mean loss: 1.570971
# accuracy: 0.559082
# ----3-----
# mean loss: 1.419820
# accuracy: 0.612793
# ----4-----
# mean loss: 1.441264
# accuracy: 0.573529
# ----0-----
# ----1-----
# eval mean loss: 1.437930
# eval accuracy: 0.587256
# eval avg class acc: 0.511307
# --- Total running time for EPOCH 001 : 0:00:44.927687 ---
# --- Total running time for MAIN : 0:01:39.351255 ---
# HyperOpt batch size selected:32
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#  50% 1/2 [01:39<01:39, 99.38s/it, best loss: 1.4379298276715464]2020-03-16 12:19:54.656561: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:19:54.657482: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-03-16 12:19:54.657614: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-16 12:19:54.657678: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-16 12:19:54.657765: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-16 12:19:54.657808: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-16 12:19:54.657845: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-16 12:19:54.657869: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-16 12:19:54.657893: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-16 12:19:54.658009: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:19:54.658825: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:19:54.660387: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-16 12:19:54.660520: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-16 12:19:54.660552: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-16 12:19:54.660570: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-16 12:19:54.660762: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:19:54.661843: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:19:54.662631: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# 2020-03-16 12:19:55.438039: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
# mean loss: 3.711066
# accuracy: 0.224121
# ----1-----
# mean loss: 2.768276
# accuracy: 0.307598
# ----2-----
# mean loss: 2.433254
# accuracy: 0.368164
# ----3-----
# mean loss: 2.130518
# accuracy: 0.423828
# ----4-----
# mean loss: 1.945285
# accuracy: 0.462891
# ----0-----
# ----1-----
# eval mean loss: 1.778975
# eval accuracy: 0.501218
# eval avg class acc: 0.396091
# --- Total running time for EPOCH 000 : 0:00:46.452252 ---
# Model saved in file: log/hyperopttiny/3/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 1.719590
# accuracy: 0.527344
# ----1-----
# mean loss: 1.599888
# accuracy: 0.539828
# ----2-----
# mean loss: 1.555232
# accuracy: 0.547852
# ----3-----
# mean loss: 1.553334
# accuracy: 0.571777
# ----4-----
# mean loss: 1.374641
# accuracy: 0.590332
# ----0-----
# ----1-----
# eval mean loss: 1.364240
# eval accuracy: 0.615666
# eval avg class acc: 0.516022
# --- Total running time for EPOCH 001 : 0:00:44.724432 ---
# --- Total running time for MAIN : 0:01:37.107574 ---
# 100% 2/2 [03:16<00:00, 98.71s/it, best loss: 1.3642402918307812]
# Run 1 - Best param found:{'batch_size': 4}
# {'state': 2, 'tid': 0, 'spec': None, 'result': {'loss': 1.4379298276715464, 'status': 'ok', 'accuracy': 0.5872564935064936, 'avg_class_accuracy': 0.5113066186305388, 'eval_time': 1584361190.6308248, 'RunParams': {'optimizer': 'adam', 'batch_size': 32, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 0, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [0]}, 'vals': {'batch_size': [4]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 18, 11, 305000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 19, 50, 680000)}
# {'state': 2, 'tid': 1, 'spec': None, 'result': {'loss': 1.3642402918307812, 'status': 'ok', 'accuracy': 0.6156655844155844, 'avg_class_accuracy': 0.5160218068199796, 'eval_time': 1584361287.7697647, 'RunParams': {'optimizer': 'adam', 'batch_size': 32, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 1, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [1]}, 'vals': {'batch_size': [4]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 19, 50, 683000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 21, 27, 820000)}
# Written trials on run 1.
# HyperOpt batch size selected:2
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#   0% 0/2 [00:00<?, ?it/s, best loss: ?]2020-03-16 12:21:31.840648: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:21:31.841574: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-03-16 12:21:31.841690: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-16 12:21:31.841749: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-16 12:21:31.841798: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-16 12:21:31.841840: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-16 12:21:31.841877: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-16 12:21:31.841918: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-16 12:21:31.841982: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-16 12:21:31.842112: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:21:31.843044: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:21:31.843875: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-16 12:21:31.843938: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-16 12:21:31.843979: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-16 12:21:31.843992: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-16 12:21:31.844129: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:21:31.845098: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:21:31.845968: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# 2020-03-16 12:21:32.469923: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
# mean loss: 7.086998
# accuracy: 0.066895
# ----1-----
# mean loss: 4.722673
# accuracy: 0.067354
# ----2-----
# mean loss: 4.166375
# accuracy: 0.084473
# ----3-----
# mean loss: 3.742342
# accuracy: 0.076660
# ----4-----
# mean loss: 3.624614
# accuracy: 0.096680
# ----0-----
# ----1-----
# eval mean loss: 81614431.508402
# eval accuracy: 0.027553
# eval avg class acc: 0.017000
# --- Total running time for EPOCH 000 : 0:02:48.016237 ---
# Model saved in file: log/hyperopttiny/3/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 3.610528
# accuracy: 0.080566
# ----1-----
# mean loss: 3.516856
# accuracy: 0.093262
# ----2-----
# mean loss: 3.409242
# accuracy: 0.111816
# ----3-----
# mean loss: 3.388746
# accuracy: 0.097656
# ----4-----
# mean loss: 3.399709
# accuracy: 0.096481
# ----0-----
# ----1-----
# eval mean loss: 21.872268
# eval accuracy: 0.078606
# eval avg class acc: 0.048500
# --- Total running time for EPOCH 001 : 0:02:41.432011 ---
# --- Total running time for MAIN : 0:05:35.239432 ---
# HyperOpt batch size selected:2
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#  50% 1/2 [05:35<05:35, 335.26s/it, best loss: 1.3642402918307812]2020-03-16 12:27:06.911396: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:27:06.912451: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-03-16 12:27:06.912566: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-16 12:27:06.912633: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-16 12:27:06.912677: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-16 12:27:06.912757: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-16 12:27:06.912830: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-16 12:27:06.912877: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-16 12:27:06.912918: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-16 12:27:06.913080: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:27:06.914169: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:27:06.915214: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-16 12:27:06.915269: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-16 12:27:06.915291: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-16 12:27:06.915305: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-16 12:27:06.915460: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:27:06.916410: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:27:06.917324: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# 2020-03-16 12:27:07.614059: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
# mean loss: 6.999861
# accuracy: 0.075243
# ----1-----
# mean loss: 4.842078
# accuracy: 0.069824
# ----2-----
# mean loss: 4.019470
# accuracy: 0.073242
# ----3-----
# mean loss: 4.011023
# accuracy: 0.076172
# ----4-----
# mean loss: 3.874005
# accuracy: 0.073242
# ----0-----
# ----1-----
# eval mean loss: 14817.665276
# eval accuracy: 0.040924
# eval avg class acc: 0.025291
# --- Total running time for EPOCH 000 : 0:02:44.730999 ---
# Model saved in file: log/hyperopttiny/3/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 3.624225
# accuracy: 0.080566
# ----1-----
# mean loss: 3.608037
# accuracy: 0.092233
# ----2-----
# mean loss: 3.564266
# accuracy: 0.068848
# ----3-----
# mean loss: 3.520510
# accuracy: 0.083496
# ----4-----
# mean loss: 3.480173
# accuracy: 0.089844
# ----0-----
# ----1-----
# eval mean loss: 343509.570473
# eval accuracy: 0.055916
# eval avg class acc: 0.034500
# --- Total running time for EPOCH 001 : 0:02:45.848457 ---
# --- Total running time for MAIN : 0:05:36.303736 ---
# 100% 2/2 [11:11<00:00, 335.58s/it, best loss: 1.3642402918307812]
# Run 2 - Best param found:{'batch_size': 4}
# {'state': 2, 'tid': 0, 'spec': None, 'result': {'loss': 1.4379298276715464, 'status': 'ok', 'accuracy': 0.5872564935064936, 'avg_class_accuracy': 0.5113066186305388, 'eval_time': 1584361190.6308248, 'RunParams': {'optimizer': 'adam', 'batch_size': 32, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 0, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [0]}, 'vals': {'batch_size': [4]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 18, 11, 305000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 19, 50, 680000)}
# {'state': 2, 'tid': 1, 'spec': None, 'result': {'loss': 1.3642402918307812, 'status': 'ok', 'accuracy': 0.6156655844155844, 'avg_class_accuracy': 0.5160218068199796, 'eval_time': 1584361287.7697647, 'RunParams': {'optimizer': 'adam', 'batch_size': 32, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 1, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [1]}, 'vals': {'batch_size': [4]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 19, 50, 683000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 21, 27, 820000)}
# {'state': 2, 'tid': 2, 'spec': None, 'result': {'loss': 21.872267921942754, 'status': 'ok', 'accuracy': 0.07860615883306321, 'avg_class_accuracy': 0.0485, 'eval_time': 1584361623.0447958, 'RunParams': {'optimizer': 'adam', 'batch_size': 2, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 2, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [2]}, 'vals': {'batch_size': [0]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 21, 27, 837000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 27, 3, 93000)}
# {'state': 2, 'tid': 3, 'spec': None, 'result': {'loss': 343509.5704733533, 'status': 'ok', 'accuracy': 0.055915721231766614, 'avg_class_accuracy': 0.0345, 'eval_time': 1584361959.3611364, 'RunParams': {'optimizer': 'adam', 'batch_size': 2, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 3, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [3]}, 'vals': {'batch_size': [0]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 27, 3, 95000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 32, 39, 414000)}
# Written trials on run 2.
# HyperOpt batch size selected:32
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#   0% 0/2 [00:00<?, ?it/s, best loss: ?]2020-03-16 12:32:43.701010: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:32:43.702000: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-03-16 12:32:43.702112: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-16 12:32:43.702156: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-16 12:32:43.702202: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-16 12:32:43.702244: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-16 12:32:43.702297: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-16 12:32:43.702337: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-16 12:32:43.702392: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-16 12:32:43.702544: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:32:43.703526: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:32:43.704282: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-16 12:32:43.704338: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-16 12:32:43.704374: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-16 12:32:43.704399: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-16 12:32:43.704538: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:32:43.705464: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:32:43.706229: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# 2020-03-16 12:32:44.330199: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
# mean loss: 4.013823
# accuracy: 0.168505
# ----1-----
# mean loss: 2.924312
# accuracy: 0.293457
# ----2-----
# mean loss: 2.409401
# accuracy: 0.379395
# ----3-----
# mean loss: 2.037085
# accuracy: 0.449219
# ----4-----
# mean loss: 2.017787
# accuracy: 0.463379
# ----0-----
# ----1-----
# eval mean loss: 1.568212
# eval accuracy: 0.577922
# eval avg class acc: 0.468188
# --- Total running time for EPOCH 000 : 0:00:47.073869 ---
# Model saved in file: log/hyperopttiny/3/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 1.854330
# accuracy: 0.490723
# ----1-----
# mean loss: 1.565406
# accuracy: 0.543457
# ----2-----
# mean loss: 1.571916
# accuracy: 0.551270
# ----3-----
# mean loss: 1.435970
# accuracy: 0.576172
# ----4-----
# mean loss: 1.363994
# accuracy: 0.600490
# ----0-----
# ----1-----
# eval mean loss: 1.306611
# eval accuracy: 0.613636
# eval avg class acc: 0.550966
# --- Total running time for EPOCH 001 : 0:00:45.247639 ---
# --- Total running time for MAIN : 0:01:38.527529 ---
# HyperOpt batch size selected:2
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#  50% 1/2 [01:38<01:38, 98.56s/it, best loss: 1.3066105486510635]2020-03-16 12:34:22.286456: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:34:22.287480: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-03-16 12:34:22.287605: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-16 12:34:22.287666: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-16 12:34:22.287713: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-16 12:34:22.287754: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-16 12:34:22.287793: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-16 12:34:22.287832: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-16 12:34:22.287871: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-16 12:34:22.288009: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:34:22.288856: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:34:22.289681: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-16 12:34:22.289780: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-16 12:34:22.289881: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-16 12:34:22.289916: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-16 12:34:22.290100: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:34:22.290963: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:34:22.291896: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# 2020-03-16 12:34:23.060528: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
# mean loss: 7.133140
# accuracy: 0.072266
# ----1-----
# mean loss: 4.958612
# accuracy: 0.080078
# ----2-----
# mean loss: 3.892052
# accuracy: 0.108010
# ----3-----
# mean loss: 3.675690
# accuracy: 0.089844
# ----4-----
# mean loss: 3.805177
# accuracy: 0.067871
# ----0-----
# ----1-----
# eval mean loss: 9225.898539
# eval accuracy: 0.027958
# eval avg class acc: 0.017250
# --- Total running time for EPOCH 000 : 0:02:54.668888 ---
# Model saved in file: log/hyperopttiny/3/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 3.562481
# accuracy: 0.082520
# ----1-----
# mean loss: 3.482889
# accuracy: 0.114258
# ----2-----
# mean loss: 3.429072
# accuracy: 0.122070
# ----3-----
# mean loss: 3.423581
# accuracy: 0.117718
# ----4-----
# mean loss: 3.474109
# accuracy: 0.094238
# ----0-----
# ----1-----
# eval mean loss: 3463.452313
# eval accuracy: 0.033630
# eval avg class acc: 0.020831
# --- Total running time for EPOCH 001 : 0:02:47.455385 ---
# --- Total running time for MAIN : 0:05:48.398281 ---
# 100% 2/2 [07:26<00:00, 173.52s/it, best loss: 1.3066105486510635]
# Run 3 - Best param found:{'batch_size': 4}
# {'state': 2, 'tid': 0, 'spec': None, 'result': {'loss': 1.4379298276715464, 'status': 'ok', 'accuracy': 0.5872564935064936, 'avg_class_accuracy': 0.5113066186305388, 'eval_time': 1584361190.6308248, 'RunParams': {'optimizer': 'adam', 'batch_size': 32, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 0, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [0]}, 'vals': {'batch_size': [4]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 18, 11, 305000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 19, 50, 680000)}
# {'state': 2, 'tid': 1, 'spec': None, 'result': {'loss': 1.3642402918307812, 'status': 'ok', 'accuracy': 0.6156655844155844, 'avg_class_accuracy': 0.5160218068199796, 'eval_time': 1584361287.7697647, 'RunParams': {'optimizer': 'adam', 'batch_size': 32, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 1, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [1]}, 'vals': {'batch_size': [4]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 19, 50, 683000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 21, 27, 820000)}
# {'state': 2, 'tid': 2, 'spec': None, 'result': {'loss': 21.872267921942754, 'status': 'ok', 'accuracy': 0.07860615883306321, 'avg_class_accuracy': 0.0485, 'eval_time': 1584361623.0447958, 'RunParams': {'optimizer': 'adam', 'batch_size': 2, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 2, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [2]}, 'vals': {'batch_size': [0]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 21, 27, 837000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 27, 3, 93000)}
# {'state': 2, 'tid': 3, 'spec': None, 'result': {'loss': 343509.5704733533, 'status': 'ok', 'accuracy': 0.055915721231766614, 'avg_class_accuracy': 0.0345, 'eval_time': 1584361959.3611364, 'RunParams': {'optimizer': 'adam', 'batch_size': 2, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 3, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [3]}, 'vals': {'batch_size': [0]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 27, 3, 95000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 32, 39, 414000)}
# {'state': 2, 'tid': 4, 'spec': None, 'result': {'loss': 1.3066105486510635, 'status': 'ok', 'accuracy': 0.6136363636363636, 'avg_class_accuracy': 0.5509661853465839, 'eval_time': 1584362057.9330049, 'RunParams': {'optimizer': 'adam', 'batch_size': 32, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 4, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [4]}, 'vals': {'batch_size': [4]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 32, 39, 435000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 34, 17, 994000)}
# {'state': 2, 'tid': 5, 'spec': None, 'result': {'loss': 3463.452312924487, 'status': 'ok', 'accuracy': 0.033630470016207455, 'avg_class_accuracy': 0.02083139534883721, 'eval_time': 1584362406.3613064, 'RunParams': {'optimizer': 'adam', 'batch_size': 2, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 5, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [5]}, 'vals': {'batch_size': [0]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 34, 17, 996000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 40, 6, 410000)}
# Written trials on run 3.
# HyperOpt batch size selected:32
# is_training_placeholder:Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
#   0% 0/2 [00:00<?, ?it/s, best loss: ?]2020-03-16 12:40:10.129698: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:40:10.130466: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-03-16 12:40:10.130622: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-16 12:40:10.130652: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-16 12:40:10.130679: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-16 12:40:10.130703: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-16 12:40:10.130743: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-16 12:40:10.130783: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-16 12:40:10.130808: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-16 12:40:10.130903: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:40:10.131579: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 12:40:10.132213: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-16 12:40:10.132254: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-16 12:40:10.132266: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-16 12:40:10.132274: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# ...
# 2020-03-16 13:16:32.326451: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-16 13:16:32.326548: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-16 13:16:32.326564: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-16 13:16:32.326573: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-16 13:16:32.326678: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 13:16:32.327663: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 13:16:32.328441: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# 2020-03-16 13:16:33.138851: W tensorflow/core/common_runtime/colocation_graph.cc:983] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# AssignAdd: CPU
# Const: GPU CPU XLA_CPU XLA_GPU
# Identity: GPU CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Assign: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   Variable (VariableV2) /device:GPU:0
#   Variable/Assign (Assign) /device:GPU:0
#   Variable/read (Identity) /device:GPU:0
#   Adam/value (Const) /device:GPU:0
#   Adam (AssignAdd) /device:GPU:0
#   save/Assign (Assign) /device:GPU:0
#
# **** EPOCH 000 ****
# ----0-----
# mean loss: 7.347291
# accuracy: 0.069824
# ----1-----
# mean loss: 4.794195
# accuracy: 0.066406
# ----2-----
# mean loss: 3.730252
# accuracy: 0.080566
# ----3-----
# mean loss: 3.728999
# accuracy: 0.080566
# ----4-----
# mean loss: 3.627807
# accuracy: 0.080704
# ----0-----
# ----1-----
# eval mean loss: 2904.803827
# eval accuracy: 0.075365
# eval avg class acc: 0.049500
# --- Total running time for EPOCH 000 : 0:02:49.897673 ---
# Model saved in file: log/hyperopttiny/3/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 3.712368
# accuracy: 0.083984
# ----1-----
# mean loss: 3.524121
# accuracy: 0.078277
# ----2-----
# mean loss: 3.471511
# accuracy: 0.080078
# ----3-----
# mean loss: 3.482178
# accuracy: 0.079590
# ----4-----
# mean loss: 3.443607
# accuracy: 0.078613
# ----0-----
# ----1-----
# eval mean loss: 510555.582441
# eval accuracy: 0.040924
# eval avg class acc: 0.025250
# --- Total running time for EPOCH 001 : 0:02:57.636666 ---
# --- Total running time for MAIN : 0:05:53.554632 ---
# 100% 2/2 [07:44<00:00, 183.78s/it, best loss: 1.3066105486510635]
# Run 10 - Best param found:{'batch_size': 4}
# {'state': 2, 'tid': 0, 'spec': None, 'result': {'loss': 1.4379298276715464, 'status': 'ok', 'accuracy': 0.5872564935064936, 'avg_class_accuracy': 0.5113066186305388, 'eval_time': 1584361190.6308248, 'RunParams': {'optimizer': 'adam', 'batch_size': 32, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 0, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [0]}, 'vals': {'batch_size': [4]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 18, 11, 305000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 19, 50, 680000)}
# {'state': 2, 'tid': 1, 'spec': None, 'result': {'loss': 1.3642402918307812, 'status': 'ok', 'accuracy': 0.6156655844155844, 'avg_class_accuracy': 0.5160218068199796, 'eval_time': 1584361287.7697647, 'RunParams': {'optimizer': 'adam', 'batch_size': 32, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 1, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [1]}, 'vals': {'batch_size': [4]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 19, 50, 683000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 21, 27, 820000)}
# {'state': 2, 'tid': 2, 'spec': None, 'result': {'loss': 21.872267921942754, 'status': 'ok', 'accuracy': 0.07860615883306321, 'avg_class_accuracy': 0.0485, 'eval_time': 1584361623.0447958, 'RunParams': {'optimizer': 'adam', 'batch_size': 2, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 2, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [2]}, 'vals': {'batch_size': [0]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 21, 27, 837000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 27, 3, 93000)}
# {'state': 2, 'tid': 3, 'spec': None, 'result': {'loss': 343509.5704733533, 'status': 'ok', 'accuracy': 0.055915721231766614, 'avg_class_accuracy': 0.0345, 'eval_time': 1584361959.3611364, 'RunParams': {'optimizer': 'adam', 'batch_size': 2, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 3, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [3]}, 'vals': {'batch_size': [0]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 27, 3, 95000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 32, 39, 414000)}
# {'state': 2, 'tid': 4, 'spec': None, 'result': {'loss': 1.3066105486510635, 'status': 'ok', 'accuracy': 0.6136363636363636, 'avg_class_accuracy': 0.5509661853465839, 'eval_time': 1584362057.9330049, 'RunParams': {'optimizer': 'adam', 'batch_size': 32, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 4, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [4]}, 'vals': {'batch_size': [4]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 32, 39, 435000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 34, 17, 994000)}
# {'state': 2, 'tid': 5, 'spec': None, 'result': {'loss': 3463.452312924487, 'status': 'ok', 'accuracy': 0.033630470016207455, 'avg_class_accuracy': 0.02083139534883721, 'eval_time': 1584362406.3613064, 'RunParams': {'optimizer': 'adam', 'batch_size': 2, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 5, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [5]}, 'vals': {'batch_size': [0]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 34, 17, 996000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 40, 6, 410000)}
# {'state': 2, 'tid': 6, 'spec': None, 'result': {'loss': 1.3269015991842592, 'status': 'ok', 'accuracy': 0.6164772727272727, 'avg_class_accuracy': 0.5283272557084849, 'eval_time': 1584362503.3575568, 'RunParams': {'optimizer': 'adam', 'batch_size': 32, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 6, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [6]}, 'vals': {'batch_size': [4]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 40, 6, 435000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 41, 43, 411000)}
# {'state': 2, 'tid': 7, 'spec': None, 'result': {'loss': 5.937649628138426, 'status': 'ok', 'accuracy': 0.14019448946515398, 'avg_class_accuracy': 0.10170348837209302, 'eval_time': 1584362695.5337448, 'RunParams': {'optimizer': 'adam', 'batch_size': 4, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 7, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [7]}, 'vals': {'batch_size': [1]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 41, 43, 413000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 44, 55, 590000)}
# {'state': 2, 'tid': 8, 'spec': None, 'result': {'loss': 40.1295468894164, 'status': 'ok', 'accuracy': 0.014586709886547812, 'avg_class_accuracy': 0.01, 'eval_time': 1584363035.3190475, 'RunParams': {'optimizer': 'adam', 'batch_size': 2, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 8, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [8]}, 'vals': {'batch_size': [0]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 44, 55, 642000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 50, 35, 385000)}
# {'state': 2, 'tid': 9, 'spec': None, 'result': {'loss': 1.4590916175927435, 'status': 'ok', 'accuracy': 0.5815746753246753, 'avg_class_accuracy': 0.48032238378085557, 'eval_time': 1584363169.2050822, 'RunParams': {'optimizer': 'adam', 'batch_size': 8, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 9, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [9]}, 'vals': {'batch_size': [2]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 50, 35, 388000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 52, 49, 254000)}
# {'state': 2, 'tid': 10, 'spec': None, 'result': {'loss': 37467.998030433395, 'status': 'ok', 'accuracy': 0.03484602917341977, 'avg_class_accuracy': 0.021500000000000002, 'eval_time': 1584363510.7921076, 'RunParams': {'optimizer': 'adam', 'batch_size': 2, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 10, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [10]}, 'vals': {'batch_size': [0]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 52, 49, 286000), 'refresh_time': datetime.datetime(2020, 3, 16, 12, 58, 30, 845000)}
# {'state': 2, 'tid': 11, 'spec': None, 'result': {'loss': 1.44083239583226, 'status': 'ok', 'accuracy': 0.560064935064935, 'avg_class_accuracy': 0.47300479522323374, 'eval_time': 1584363621.4463017, 'RunParams': {'optimizer': 'adam', 'batch_size': 16, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 11, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [11]}, 'vals': {'batch_size': [3]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 12, 58, 30, 848000), 'refresh_time': datetime.datetime(2020, 3, 16, 13, 0, 21, 504000)}
# {'state': 2, 'tid': 12, 'spec': None, 'result': {'loss': 1.4063544683642202, 'status': 'ok', 'accuracy': 0.5799512987012987, 'avg_class_accuracy': 0.4727183558412794, 'eval_time': 1584363732.635616, 'RunParams': {'optimizer': 'adam', 'batch_size': 16, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 12, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [12]}, 'vals': {'batch_size': [3]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 13, 0, 21, 544000), 'refresh_time': datetime.datetime(2020, 3, 16, 13, 2, 12, 690000)}
# {'state': 2, 'tid': 13, 'spec': None, 'result': {'loss': 1.9587227403149976, 'status': 'ok', 'accuracy': 0.4525162337662338, 'avg_class_accuracy': 0.37447774374020226, 'eval_time': 1584363869.8321898, 'RunParams': {'optimizer': 'adam', 'batch_size': 8, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 13, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [13]}, 'vals': {'batch_size': [2]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 13, 2, 12, 692000), 'refresh_time': datetime.datetime(2020, 3, 16, 13, 4, 29, 890000)}
# {'state': 2, 'tid': 14, 'spec': None, 'result': {'loss': 2.871027337963809, 'status': 'ok', 'accuracy': 0.23176661264181522, 'avg_class_accuracy': 0.14422093023255816, 'eval_time': 1584364068.165733, 'RunParams': {'optimizer': 'adam', 'batch_size': 4, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 14, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [14]}, 'vals': {'batch_size': [1]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 13, 4, 29, 955000), 'refresh_time': datetime.datetime(2020, 3, 16, 13, 7, 48, 219000)}
# {'state': 2, 'tid': 15, 'spec': None, 'result': {'loss': 1.5367056363588805, 'status': 'ok', 'accuracy': 0.5430194805194806, 'avg_class_accuracy': 0.4698122971528287, 'eval_time': 1584364179.7290103, 'RunParams': {'optimizer': 'adam', 'batch_size': 16, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 15, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [15]}, 'vals': {'batch_size': [3]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 13, 7, 48, 221000), 'refresh_time': datetime.datetime(2020, 3, 16, 13, 9, 39, 792000)}
# {'state': 2, 'tid': 16, 'spec': None, 'result': {'loss': 6.328309024462244, 'status': 'ok', 'accuracy': 0.19003241491085898, 'avg_class_accuracy': 0.14159302325581394, 'eval_time': 1584364378.3590412, 'RunParams': {'optimizer': 'adam', 'batch_size': 4, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 16, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [16]}, 'vals': {'batch_size': [1]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 13, 9, 39, 982000), 'refresh_time': datetime.datetime(2020, 3, 16, 13, 12, 58, 413000)}
# {'state': 2, 'tid': 17, 'spec': None, 'result': {'loss': 1.7684574018825183, 'status': 'ok', 'accuracy': 0.5308441558441559, 'avg_class_accuracy': 0.4834417442100166, 'eval_time': 1584364477.2038686, 'RunParams': {'optimizer': 'adam', 'batch_size': 32, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 17, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [17]}, 'vals': {'batch_size': [4]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 13, 12, 58, 415000), 'refresh_time': datetime.datetime(2020, 3, 16, 13, 14, 37, 265000)}
# {'state': 2, 'tid': 18, 'spec': None, 'result': {'loss': 1.3878296501450724, 'status': 'ok', 'accuracy': 0.6002435064935064, 'avg_class_accuracy': 0.47712482322033817, 'eval_time': 1584364588.4069598, 'RunParams': {'optimizer': 'adam', 'batch_size': 16, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 18, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [18]}, 'vals': {'batch_size': [3]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 13, 14, 37, 450000), 'refresh_time': datetime.datetime(2020, 3, 16, 13, 16, 28, 461000)}
# {'state': 2, 'tid': 19, 'spec': None, 'result': {'loss': 510555.58244143875, 'status': 'ok', 'accuracy': 0.04092382495948136, 'avg_class_accuracy': 0.02525, 'eval_time': 1584364941.97723, 'RunParams': {'optimizer': 'adam', 'batch_size': 2, 'num_point': 1024, 'momentum': 0.9, 'max_epoch': 2}}, 'misc': {'tid': 19, 'cmd': ('domain_attachment', 'FMinIter_Domain'), 'workdir': None, 'idxs': {'batch_size': [19]}, 'vals': {'batch_size': [0]}}, 'exp_key': None, 'owner': None, 'version': 0, 'book_time': datetime.datetime(2020, 3, 16, 13, 16, 28, 463000), 'refresh_time': datetime.datetime(2020, 3, 16, 13, 22, 22, 33000)}
# Written trials on run 10.

# %%
import os
#os.chdir('/content/gdrive/My Drive/KE5208_Sense_Making/Code/pointnet00/')
os.chdir('/content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/')

# !python evaluate.py 
#--model_path="log/normal5/model.ckpt"
# Out:
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/models/pointnet_cls.py:13: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/models/pointnet_cls.py:24: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:21: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:48: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:368: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:Variable += will be deprecated. Use variable.assign_add if you want assignment to the variable value or 'x = x + y' if you want a new python Tensor object.
# WARNING:tensorflow:Variable += will be deprecated. Use variable.assign_add if you want assignment to the variable value or 'x = x + y' if you want a new python Tensor object.
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/utils/tf_util.py:573: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /content/drive/My Drive/pointnetf/PointnetEnhanced/pointnet/models/pointnet_cls.py:80: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From evaluate.py:69: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From evaluate.py:72: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From evaluate.py:76: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-03-16 13:32:21.846731: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-03-16 13:32:21.846979: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x15cb9c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-03-16 13:32:21.847014: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-03-16 13:32:21.849566: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-03-16 13:32:21.962732: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 13:32:21.963789: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x15cbb80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-03-16 13:32:21.963822: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-03-16 13:32:21.964088: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 13:32:21.964945: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2020-03-16 13:32:21.965302: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-16 13:32:21.967209: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-16 13:32:21.968854: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-16 13:32:21.969221: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-16 13:32:21.971013: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-16 13:32:21.973049: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-16 13:32:21.977172: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-16 13:32:21.977387: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 13:32:21.978321: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 13:32:21.979147: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-16 13:32:21.979209: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-16 13:32:21.980757: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-16 13:32:21.980786: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-16 13:32:21.980799: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-16 13:32:21.980936: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 13:32:21.981894: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-16 13:32:21.982719: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# Device mapping:
# /job:localhost/replica:0/task:0/device:XLA_CPU:0 -> device: XLA_CPU device
# /job:localhost/replica:0/task:0/device:XLA_GPU:0 -> device: XLA_GPU device
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# 2020-03-16 13:32:21.983416: I tensorflow/core/common_runtime/direct_session.cc:359] Device mapping:
# /job:localhost/replica:0/task:0/device:XLA_CPU:0 -> device: XLA_CPU device
# /job:localhost/replica:0/task:0/device:XLA_GPU:0 -> device: XLA_GPU device
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
#
# Traceback (most recent call last):
#   File "evaluate.py", line 170, in <module>
#     evaluate(num_votes=1)
#   File "evaluate.py", line 79, in evaluate
#     saver.restore(sess, MODEL_PATH)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py", line 1282, in restore
#     checkpoint_prefix)
# ValueError: The passed save_path is not a valid checkpoint: log/model.ckpt

# %% [markdown]
# ## Running tensorboard with the pointnet result
# https://www.dlology.com/blog/quick-guide-to-run-tensorboard-in-google-colab/

# %%
str = ""
if str:
  print ("not empty")

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip
# Out:
# --2020-03-16 13:22:52--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 34.197.77.37, 52.20.119.24, 52.5.204.126, ...
# Connecting to bin.equinox.io (bin.equinox.io)|34.197.77.37|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13773305 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  13.13M  6.06MB/s    in 2.2s
#
# 2020-03-16 13:22:55 (6.06 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13773305/13773305]
#
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok

# %%
os.chdir('/content/drive/My Drive/GitHub/PointnetEnhanced/pointnet')

LOG_DIR = './log/11'
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR)
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-a821ad453ea2> in <module>()
# ----> 1 os.chdir('/content/drive/My Drive/GitHub/PointnetEnhanced/pointnet')
#       2
#       3 LOG_DIR = './log/11'
#       4 get_ipython().system_raw(
#       5     'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/GitHub/PointnetEnhanced/pointnet'

# %%
get_ipython().system_raw('./ngrok http 6006 &')

# %%
! curl -s http://localhost:4040/api/tunnels | python -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"

# %% [markdown]
# ## Running pointnet 2

# %%
import os
os.chdir('/content/gdrive/My Drive/KE5208_Sense_Making/Code/pointnet2/pointnet2/tf_ops/sampling')
# !bash tf_sampling_compile.sh

# %%
import os
os.chdir('/content/gdrive/My Drive/KE5208_Sense_Making/Code/pointnet2/pointnet2/tf_ops/grouping')
# !bash tf_grouping_compile.sh

# %%
import os
os.chdir('/content/gdrive/My Drive/KE5208_Sense_Making/Code/pointnet2/pointnet2/tf_ops/3d_interpolation')
# !bash tf_interpolate_compile.sh

# %%
import os
os.chdir('/content/gdrive/My Drive/KE5208_Sense_Making/Code/pointnet2/pointnet2')

# !python train.py #--gpu 0 # train_multi_gpu.py #--num_gpu=8

# %%
import os
os.chdir('/content/gdrive/My Drive/KE5208_Sense_Making/Code/pointnet2/pointnet2')

# !python evaluate.py

# %% [markdown]
# ## Running tensorboard with the pointnet 2 result
# https://www.dlology.com/blog/quick-guide-to-run-tensorboard-in-google-colab/

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip

# %%
#os.chdir('/content/gdrive/My Drive/KE5208_Sense_Making/Code/pointnet2/pointnet2')
os.chdir('/content/gdrive/My Drive/GitHub/PointnetEnhanced/pointnet2/pointnet2')

LOG_DIR = './log'
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6007 &'
    .format(LOG_DIR)
)

# %%
get_ipython().system_raw('./ngrok http 6007 &')

# %%
! curl -s http://localhost:4040/api/tunnels | python -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"

# %% [markdown]
# ## Running 3DmFV-Net
#
# Mount the google drive and point to the folder containing the train.py and run the code from there with a slight modification.

# %%
import os
os.chdir('/content/gdrive/My Drive/KE5208_Sense_Making/Code/3DmFV-Net-master')
#os.chdir('/content/gdrive/My Drive/GitHub/PointnetEnhanced/pointnet/')


# !python train_cls.py --gpu=0 #--batch_size=128
